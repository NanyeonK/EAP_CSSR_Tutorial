# %% [markdown]
# # Preprocess for analysis

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import tabulate as tb

import wrds

from statsmodels.regression.rolling import RollingOLS
from statsmodels.tsa.ar_model import AutoReg
from scipy.stats import skew, kurtosis, rankdata
import statsmodels.api as sm

# %%
# For testing 
import time

# %%
conn = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %% [markdown]
# # Beta

# %% [markdown]
# According to the CAPM, each expected stock return is equal to the risk-free return plus the market beta multiplied by the market risk premium.
# Thus,
# $$E[R_{i,t}] = R_{f,t} + \beta_i (E[R_{m,t}] - R_{f,t})$$
# where, beta of security $i$ is
# $$\beta_i = \frac{Cov(R_{i,t}, R_{m,t})}{Var(R_{m,t})}$$
# where, $R_{i,t}, R_{m,t}$ is the return of security $i$ and market portfolio

# %% [markdown]
# There are several empirically testable predictions.
# In this chapter we show two of them.
#
# 1. The CAPM predicts that cross-sectional variation in expected returns is driven by variation in the security's beta.
#
#     1.1 Test the cross-sectional ability of beta to predict future excess returns.
#
#     Fama and MacBeth (1973) finds the positive correlation between excess returns and the beta, but recent studies (Fama and French 1992; 1993, and others) fail to find the correlation.
#
#     1.2 Test cross-sectional ability of other variables to predict future excess returns.
#
#     We call these variables as "anomalies".
#
#
# 2. Average excess returns, after accounting for effect of beta, should be zero.
#
#     We can find this evidence by examining the intercept ($\alpha$) term of cross-sectional regressions of security excess returns on estimates of beta.
#
#     If CAPM can predict stock returns, intercept should be 0.

# %% [markdown]
# # 1. Estimating beta

# %% [markdown]
# $r_{i,t} = \alpha_i + \beta_i MKT_t + \epsilon_{i,t}$
#
# where $r_{i,t}$ and $MKT_t$ is the excess returns of stock $i$ and market portfolio(market factor) during $t$.
#
#
# in CAPM, $\alpha_i$ should be zero.
#
# in Python code
#
# ```python
# r_it = alpha_i + beta_i * MKT_it + epsilon_it
# ```

# %% [markdown]
# There is a difference in the period and length of data used to estimate market beta.
#
# Most commonly, market beta during $t$ is estimated using only data up to and including $t$.
#
# The most popular beta estimates cover $t-11$ to $t$ and estimate $t+1$.
#
# For the quality of the estimate, it is reasonable to fit using at least 200 data points over a 12-month period.
#
# Another common approach is to use the excess returns of monthly returns over 5 years.

# %% [markdown]
# In this chapter, using 9 combination of estimation periods and data frequency.

# %% [markdown]
# Five using daily data, 1M, 3M, 6M, 12M, and 24M, require 15days, 50 days, 100days, 200days and 450 days for valid return data.
#
# We denote these estimates of market beta, caculated using daily excess return data, as $\beta^{kM}$, where $k \in \{1,3,6,12,24\}$.
#
# The daily stock return data come from __crsp.dsf__, and daily MKT factor returns and dailiy risk free rates come from Kenneth French's data library.

# %% [markdown]
# #### Data from WRDS

# %%
# Data description for the CRSP daily stock file
conn.describe_table(library='crsp', table='dsf')
# Out:
# Approximately 105258384 rows in crsp.dsf.
#        name  nullable              type  \
# 0     cusip      True        VARCHAR(8)
# 1    permno      True           INTEGER
# 2    permco      True           INTEGER
# 3    issuno      True           INTEGER
# 4     hexcd      True          SMALLINT
# 5    hsiccd      True           INTEGER
# 6      date      True              DATE
# 7     bidlo      True    NUMERIC(11, 5)
# 8     askhi      True    NUMERIC(11, 5)
# 9       prc      True    NUMERIC(11, 5)
# 10      vol      True    NUMERIC(10, 0)
# 11      ret      True    NUMERIC(10, 6)
# 12      bid      True    NUMERIC(11, 5)
# 13      ask      True    NUMERIC(11, 5)
# 14   shrout      True  DOUBLE PRECISION
# 15   cfacpr      True  DOUBLE PRECISION
# 16  cfacshr      True  DOUBLE PRECISION
# 17  openprc      True    NUMERIC(11, 5)
# 18   numtrd      True           INTEGER
# 19     retx      True    NUMERIC(10, 6)
#
#                                     comment
# 0                              CUSIP Header
# 1                 Permanent Security Number
# 2                  Permanent Company Number
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18                         Number of Trades
# 19                Returns without Dividends

# %%
# Data description for fama french factors daily
conn.describe_table(library='ff', table='factors_daily')
# Out:
# Approximately 25773 rows in ff.factors_daily.
#     name  nullable           type  \
# 0   date      True           DATE
# 1  mktrf      True  NUMERIC(8, 6)
# 2    smb      True  NUMERIC(8, 6)
# 3    hml      True  NUMERIC(8, 6)
# 4     rf      True  NUMERIC(7, 5)
# 5    umd      True  NUMERIC(8, 6)
#
#                                              comment
# 0                                               None
# 1                        Excess Return on the Market
# 2                             Small-Minus-Big Return
# 3                              High-Minus-Low Return
# 4  Risk-Free Return Rate (One Month Treasury Bill...
# 5                                           Momentum

# %%
conn = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
# Download the data from the CRSP daily stock file
crsp_d = conn.raw_sql("""
                      SELECT permno, date, ret, retx, prc, shrout
                      FROM crsp.dsf
                      WHERE date <= '2012-12-31'
                      """)

# %%
crsp_d.to_csv("C:/Users/YeonChan Kang/Desktop/Local_repo/EAP_CSSR_Tutorial/data/crsp_d.csv", index=False)

# %%
crsp_d
# Out:
#         permno        date       ret      retx      prc    shrout
# 0        10000  1986-01-07       NaN       NaN  -2.5625    3680.0
# 1        10000  1986-01-08 -0.024390 -0.024390  -2.5000    3680.0
# 2        10000  1986-01-09  0.000000  0.000000  -2.5000    3680.0
# 3        10000  1986-01-10  0.000000  0.000000  -2.5000    3680.0
# 4        10000  1986-01-13  0.050000  0.050000  -2.6250    3680.0
# ...        ...         ...       ...       ...      ...       ...
# 143732   93436  2012-12-24  0.008235  0.008235  34.2800  113779.0
# 143733   93436  2012-12-26 -0.020128 -0.020128  33.5900  113779.0
# 143734   93436  2012-12-27  0.002977  0.002977  33.6900  113779.0
# 143735   93436  2012-12-28 -0.013951 -0.013951  33.2200  113779.0
# 143736   93436  2012-12-31  0.019567  0.019567  33.8700  114214.0
#
# [83643737 rows x 6 columns]

# %%
# import the data from local
crsp_d = pd.read_csv("C:/Users/YeonChan Kang/Desktop/Local_repo/EAP_CSSR_Tutorial/data/crsp_d.csv", index_col=0)

# %%
# Convert the date column to datetime
crsp_d['date'] = pd.to_datetime(crsp_d['date'])

# %%
crsp_d
# Out:
#         permno       date       ret      retx      prc    shrout
# 0        10000 1986-01-07       NaN       NaN  -2.5625    3680.0
# 1        10000 1986-01-08 -0.024390 -0.024390  -2.5000    3680.0
# 2        10000 1986-01-09  0.000000  0.000000  -2.5000    3680.0
# 3        10000 1986-01-10  0.000000  0.000000  -2.5000    3680.0
# 4        10000 1986-01-13  0.050000  0.050000  -2.6250    3680.0
# ...        ...        ...       ...       ...      ...       ...
# 143732   93436 2012-12-24  0.008235  0.008235  34.2800  113779.0
# 143733   93436 2012-12-26 -0.020128 -0.020128  33.5900  113779.0
# 143734   93436 2012-12-27  0.002977  0.002977  33.6900  113779.0
# 143735   93436 2012-12-28 -0.013951 -0.013951  33.2200  113779.0
# 143736   93436 2012-12-31  0.019567  0.019567  33.8700  114214.0
#
# [83643737 rows x 6 columns]

# %%
# Download the data from fama french factors daily
ff_d = conn.raw_sql("""
                    SELECT date, mktrf, rf
                    FROM ff.factors_daily
                    WHERE date <= '2012-12-31'
                    """)

# %%
ff_d['date'] = pd.to_datetime(ff_d['date'])

# %%
ff_d
# Out:
#             date   mktrf       rf
# 0     1926-07-01  0.0010  0.00009
# 1     1926-07-02  0.0045  0.00009
# 2     1926-07-06  0.0017  0.00009
# 3     1926-07-07  0.0009  0.00009
# 4     1926-07-08  0.0021  0.00009
# ...          ...     ...      ...
# 22876 2012-12-24 -0.0024  0.00001
# 22877 2012-12-26 -0.0054  0.00001
# 22878 2012-12-27 -0.0011  0.00001
# 22879 2012-12-28 -0.0100  0.00001
# 22880 2012-12-31  0.0171  0.00001
#
# [22881 rows x 3 columns]

# %%
# Merge daily dataset
daily_data = pd.merge(crsp_d, ff_d, on='date', how='left')

# %%
daily_data
# Out:
#           permno       date       ret      retx      prc    shrout   mktrf  \
# 0          10000 1986-01-07       NaN       NaN  -2.5625    3680.0  0.0138
# 1          10000 1986-01-08 -0.024390 -0.024390  -2.5000    3680.0 -0.0216
# 2          10000 1986-01-09  0.000000  0.000000  -2.5000    3680.0 -0.0117
# 3          10000 1986-01-10  0.000000  0.000000  -2.5000    3680.0 -0.0002
# 4          10000 1986-01-13  0.050000  0.050000  -2.6250    3680.0  0.0028
# ...          ...        ...       ...       ...      ...       ...     ...
# 83643732   93436 2012-12-24  0.008235  0.008235  34.2800  113779.0 -0.0024
# 83643733   93436 2012-12-26 -0.020128 -0.020128  33.5900  113779.0 -0.0054
# 83643734   93436 2012-12-27  0.002977  0.002977  33.6900  113779.0 -0.0011
# 83643735   93436 2012-12-28 -0.013951 -0.013951  33.2200  113779.0 -0.0100
# 83643736   93436 2012-12-31  0.019567  0.019567  33.8700  114214.0  0.0171
#
#                rf
# 0         0.00025
# 1         0.00025
# 2         0.00025
# 3         0.00025
# 4         0.00025
# ...           ...
# 83643732  0.00001
# 83643733  0.00001
# 83643734  0.00001
# 83643735  0.00001
# 83643736  0.00001
#
# [83643737 rows x 8 columns]

# %%
# Calculate excess return
daily_data['exret'] = daily_data['ret'] - daily_data['rf']

# %%
daily_data
# Out:
#           permno       date       ret      retx      prc    shrout   mktrf  \
# 0          10000 1986-01-07       NaN       NaN  -2.5625    3680.0  0.0138
# 1          10000 1986-01-08 -0.024390 -0.024390  -2.5000    3680.0 -0.0216
# 2          10000 1986-01-09  0.000000  0.000000  -2.5000    3680.0 -0.0117
# 3          10000 1986-01-10  0.000000  0.000000  -2.5000    3680.0 -0.0002
# 4          10000 1986-01-13  0.050000  0.050000  -2.6250    3680.0  0.0028
# ...          ...        ...       ...       ...      ...       ...     ...
# 83643732   93436 2012-12-24  0.008235  0.008235  34.2800  113779.0 -0.0024
# 83643733   93436 2012-12-26 -0.020128 -0.020128  33.5900  113779.0 -0.0054
# 83643734   93436 2012-12-27  0.002977  0.002977  33.6900  113779.0 -0.0011
# 83643735   93436 2012-12-28 -0.013951 -0.013951  33.2200  113779.0 -0.0100
# 83643736   93436 2012-12-31  0.019567  0.019567  33.8700  114214.0  0.0171
#
#                rf     exret
# 0         0.00025       NaN
# 1         0.00025 -0.024640
# 2         0.00025 -0.000250
# 3         0.00025 -0.000250
# 4         0.00025  0.049750
# ...           ...       ...
# 83643732  0.00001  0.008225
# 83643733  0.00001 -0.020138
# 83643734  0.00001  0.002967
# 83643735  0.00001 -0.013961
# 83643736  0.00001  0.019557
#
# [83643737 rows x 9 columns]

# %% [markdown]
# ##### using the package function from nafitools

# %%
# Later Updated

# %% [markdown]
# #### Cleansing data

# %% [markdown]
# Handling Missing data

# %% [markdown]
# When we use CRSP and K French library data, we can just drop the missing values.
#
# For more on Missing data, see [[url]]

# %%
len(daily_data)
# Out:
# 83643737

# %%
daily_data.isna().sum()
# Out:
# permno          0
# date            0
# ret       1741702
# retx      1741702
# prc       1708339
# shrout          0
# mktrf       79472
# rf          79472
# exret     1818524
# dtype: int64

# %%
daily_data.dropna(inplace=True)

# %%
len(daily_data)
# Out:
# 81825213

# %%
daily_data.isna().sum()
# Out:
# permno    0
# date      0
# ret       0
# retx      0
# prc       0
# shrout    0
# mktrf     0
# rf        0
# exret     0
# dtype: int64

# %% [markdown]
# PRC adjust

# %% [markdown]
# If we use the CRSP price, apply the absolute value to the price.

# %%
daily_data['prc'] = daily_data['prc'].abs()

# %%
# Check the minimum price is greater than 0
daily_data['prc'].min()
# Out:
# 0.0039

# %%
daily_data
# Out:
#           permno       date       ret      retx     prc    shrout   mktrf  \
# 1          10000 1986-01-08 -0.024390 -0.024390   2.500    3680.0 -0.0216
# 2          10000 1986-01-09  0.000000  0.000000   2.500    3680.0 -0.0117
# 3          10000 1986-01-10  0.000000  0.000000   2.500    3680.0 -0.0002
# 4          10000 1986-01-13  0.050000  0.050000   2.625    3680.0  0.0028
# 5          10000 1986-01-14  0.047619  0.047619   2.750    3680.0  0.0001
# ...          ...        ...       ...       ...     ...       ...     ...
# 83643732   93436 2012-12-24  0.008235  0.008235  34.280  113779.0 -0.0024
# 83643733   93436 2012-12-26 -0.020128 -0.020128  33.590  113779.0 -0.0054
# 83643734   93436 2012-12-27  0.002977  0.002977  33.690  113779.0 -0.0011
# 83643735   93436 2012-12-28 -0.013951 -0.013951  33.220  113779.0 -0.0100
# 83643736   93436 2012-12-31  0.019567  0.019567  33.870  114214.0  0.0171
#
#                rf     exret
# 1         0.00025 -0.024640
# 2         0.00025 -0.000250
# 3         0.00025 -0.000250
# 4         0.00025  0.049750
# 5         0.00025  0.047369
# ...           ...       ...
# 83643732  0.00001  0.008225
# 83643733  0.00001 -0.020138
# 83643734  0.00001  0.002967
# 83643735  0.00001 -0.013961
# 83643736  0.00001  0.019557
#
# [81825213 rows x 9 columns]

# %% [markdown]
# In this chapter we will use Winsorize.
#
# For more on Winsorize, see Chap. 1. Preliminaries.

# %%
def winsorize(data, col=False, except_col=['permno', 'date'], lower_bound=0.01, upper_bound=0.99):
    """
    Winsorizes the input data by replacing extreme values with the nearest values within the specified quantiles.
    if col = "column A", the function will only winsorize the specified "column A".

    Parameters:
    data (pd.Series or pd.DataFrame): The data to be winsorized.
    column (str or bool): The column to be winsorized or False to winsorize all columns. Defaults to False.
    except_col (str or bool): The column to be excluded from winsorization or False to winsorize all columns. Defaults to ['permno', 'date'].
                                For CRSP, exclude the permno and date columns. Otherwise, specify the id and date columns that match your data.
    lower (float): The lower quantile threshold. Defaults to 0.01.
    upper (float): The upper quantile threshold. Defaults to 0.99.
    copy (bool): Whether to return a copy of the data or to modify it in place. Defaults to True.
    
    Returns:
        pd.Series or pd.DataFrame: The winsorized data.
    """
    
    if except_col:
        except_df = data[except_col]
        data = data.drop(columns=except_col)
    
    else:
        print("There are no columns to be excluded")
    
    if col:
        data = data[col]

        print(f"Original maximum of {col}: {data.max()} and Original minimum of {col}: {data.min()}\n")

        qtl = data.quantile([lower_bound, upper_bound])
        
        # Winsorize the data
        data = np.where(data < qtl.loc[lower_bound], qtl.loc[lower_bound], data)
        data = np.where(data > qtl.loc[upper_bound], qtl.loc[upper_bound], data)
        
        print(f"New maximum of {col}: {data.max()} and New minimum of {col}: {data.min()}\n \n")
    
    else:
        for col in data.columns:
            col_data = data[col]
            
            print(f"Original maximum of {col}: {col_data.max()} and Original minimum of {col}: {col_data.min()}\n")
            
            qtl = col_data.quantile([lower_bound, upper_bound])
            
            # Winsorize the data
            col_data = np.where(col_data < qtl.loc[lower_bound], qtl.loc[lower_bound], col_data)
            col_data = np.where(col_data > qtl.loc[upper_bound], qtl.loc[upper_bound], col_data)
            
            print(f"New maximum of {col}: {col_data.max()} and New minimum of {col}: {col_data.min()}\n \n")
            
            data[col] = col_data
    
    if except_col:
        data = pd.concat([except_df, data], axis=1)
    
    return data

# %%
# French data is already in clean format so we will only winsorize the CRSP data
# shrout is also no need to be winsorized since it is the number of shares outstanding
daily_data = winsorize(data=daily_data, col=False, except_col=['permno', 'date', 'mktrf', 'rf', 'shrout'])
# Out:
# Original maximum of ret: 19.0 and Original minimum of ret: -0.971698
#
# New maximum of ret: 0.130435 and New minimum of ret: -0.111111
#
#
# Original maximum of retx: 19.0 and Original minimum of retx: -0.971698
#
# New maximum of retx: 0.130435 and New minimum of retx: -0.111111
#
#
# Original maximum of prc: 149200.0 and Original minimum of prc: 0.0039
#
# New maximum of prc: 103.0 and New minimum of prc: 0.25
#
#
# Original maximum of exret: 18.99999 and Original minimum of exret: -0.971908
#
# New maximum of exret: 0.130195 and New minimum of exret: -0.111321

# %%
daily_data
# Out:
#           permno       date   mktrf       rf    shrout       ret      retx  \
# 1          10000 1986-01-08 -0.0216  0.00025    3680.0 -0.024390 -0.024390
# 2          10000 1986-01-09 -0.0117  0.00025    3680.0  0.000000  0.000000
# 3          10000 1986-01-10 -0.0002  0.00025    3680.0  0.000000  0.000000
# 4          10000 1986-01-13  0.0028  0.00025    3680.0  0.050000  0.050000
# 5          10000 1986-01-14  0.0001  0.00025    3680.0  0.047619  0.047619
# ...          ...        ...     ...      ...       ...       ...       ...
# 83643732   93436 2012-12-24 -0.0024  0.00001  113779.0  0.008235  0.008235
# 83643733   93436 2012-12-26 -0.0054  0.00001  113779.0 -0.020128 -0.020128
# 83643734   93436 2012-12-27 -0.0011  0.00001  113779.0  0.002977  0.002977
# 83643735   93436 2012-12-28 -0.0100  0.00001  113779.0 -0.013951 -0.013951
# 83643736   93436 2012-12-31  0.0171  0.00001  114214.0  0.019567  0.019567
#
#              prc     exret
# 1          2.500 -0.024640
# 2          2.500 -0.000250
# 3          2.500 -0.000250
# 4          2.625  0.049750
# 5          2.750  0.047369
# ...          ...       ...
# 83643732  34.280  0.008225
# 83643733  33.590 -0.020138
# 83643734  33.690  0.002967
# 83643735  33.220 -0.013961
# 83643736  33.870  0.019557
#
# [81825213 rows x 9 columns]

# %% [markdown]
# Four monthly estimation periods.
#
# Using 1,2,3, and 5 years requiring 10,20,24 and 24 valid montlhy excess returns observations.
#
# 24 monthly data points caculate beta for 5 year follows common prcatiece when using monthly data to estimate beta.
#
# We denote these estimates of market beta, caculated using monthly excess return data, as $\beta^{kY}$, where $k \in \{1,2,3,5\}$.
#
# The daily stock return data come from __crsp.msf__, and monthly MKT factor returns and risk free rates come from Kenneth French's data library.

# %%
# Data description for the CRSP monthly stock file
conn.describe_table(library='crsp', table='msf')
# Out:
# Approximately 5037353 rows in crsp.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True           INTEGER
# 2     permco      True           INTEGER
# 3     issuno      True           INTEGER
# 4      hexcd      True          SMALLINT
# 5     hsiccd      True           INTEGER
# 6       date      True              DATE
# 7      bidlo      True    NUMERIC(11, 5)
# 8      askhi      True    NUMERIC(11, 5)
# 9        prc      True    NUMERIC(11, 5)
# 10       vol      True    NUMERIC(10, 0)
# 11       ret      True    NUMERIC(10, 6)
# 12       bid      True    NUMERIC(11, 5)
# 13       ask      True    NUMERIC(11, 5)
# 14    shrout      True  DOUBLE PRECISION
# 15    cfacpr      True  DOUBLE PRECISION
# 16   cfacshr      True  DOUBLE PRECISION
# 17    altprc      True    NUMERIC(11, 5)
# 18    spread      True    NUMERIC(10, 5)
# 19  altprcdt      True              DATE
# 20      retx      True    NUMERIC(10, 6)
#
#                                     comment
# 0                              CUSIP Header
# 1                                    PERMNO
# 2                                    PERMCO
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18               Spread Between Bid and Ask
# 19                     Alternate Price Date
# 20                Returns without Dividends

# %%
# Data description for fama french factors daily
conn.describe_table(library='ff', table='factors_monthly')
# Out:
# Approximately 1176 rows in ff.factors_monthly.
#      name  nullable              type  \
# 0    date      True              DATE
# 1   mktrf      True     NUMERIC(8, 6)
# 2     smb      True     NUMERIC(8, 6)
# 3     hml      True     NUMERIC(8, 6)
# 4      rf      True     NUMERIC(7, 5)
# 5    year      True  DOUBLE PRECISION
# 6   month      True  DOUBLE PRECISION
# 7     umd      True     NUMERIC(8, 6)
# 8  dateff      True              DATE
#
#                                              comment
# 0  Date (SAS). Eventus Format - First day of the ...
# 1                        Excess Return on the Market
# 2                             Small-Minus-Big Return
# 3                              High-Minus-Low Return
# 4  Risk-Free Return Rate (One Month Treasury Bill...
# 5                                               Year
# 6                                              Month
# 7                                    Momentum Factor
# 8          Date (SAS). Last Trading Day of the Month

# %%
crsp_m = conn.raw_sql("""
                      SELECT permno, date, ret, retx, prc, shrout
                      FROM crsp.msf
                      WHERE date <= '2012-12-31'
                      """)

# %%
# Download the data from fama french factors daily
ff_m = conn.raw_sql("""
                    SELECT date, mktrf, rf
                    FROM ff.factors_monthly
                    WHERE date <= '2012-12-31'
                    """)

# %% [markdown]
# ##### using the package function from nafitools

# %%
# Later Updated

# %% [markdown]
# #### Cleansing data

# %%
test_data = daily_data[daily_data['date'] > '2005-01-01'][['permno', 'date', 'ret', 'mktrf']]

# %% [markdown]
# #### CAPM beta, Market beta (Fama and Macbeth, 1973)

# %%
def cal_beta(data, date, id, ret, mkt, period, only_cal=False):
    """
    Calculate rolling beta, alpha, and their t-values for each group in the dataset.
    
    Parameters:
    data (pd.DataFrame): The dataset containing the required columns.
    date (str): The date column in the dataset.
    id (str): The column
    ret (str): The column 
    mkt (str): The column 
    period (str): The rolling window period. Choose from '1M', '3M', '6M', '12M', '24M'.
    dataframe (bool): Whether to return the updated dataframe with the calculated values. Defaults to False. 
                        If True, the function will return the updated dataframe. 
                        If False, the function will return a list of dataframes.
    
    Returns:
        pd.DataFrame or list: The updated dataframe with the calculated values or a list of dataframes containing the calculated values
    """
    
    # Define rolling window size and minimum valid days based on period
    period_mapping = {
        '1M': {'window_size': 21, 'min_valid_days': 15},
        '3M': {'window_size': 63, 'min_valid_days': 50},
        '6M': {'window_size': 126, 'min_valid_days': 100},
        '12M': {'window_size': 252, 'min_valid_days': 200},
        '24M': {'window_size': 504, 'min_valid_days': 450}
    }
    
    if period not in period_mapping:
        raise ValueError(f"Invalid period. Please choose from {list(period_mapping.keys())}")
    
    window_size = period_mapping[period]['window_size']
    min_valid_days = period_mapping[period]['min_valid_days']
    
    results_dict = {}
    
    for f_id, firm in data.groupby(id):
        firm_len = len(firm)
        if firm_len < min_valid_days:
            print(f"Skipping {f_id} due to insufficient data (size: {firm_len})")
            continue  # If the data is less than the minimum requirement, skip it.

        # When data length is less than window_size, adjust window_size to data length
        actual_window_size = min(firm_len, window_size)

        X = sm.add_constant(firm[mkt])
        y = firm[ret]
        
        model = RollingOLS(y, X, actual_window_size, min_nobs=min_valid_days)
        results = model.fit()
        
        firm['beta'] = results.params[mkt]
        firm['beta_se'] = results.bse[mkt]
        firm['beta_t'] = results.tvalues[mkt] 
        firm['alpha'] = results.params['const']
        firm['alpha_se'] = results.bse['const']
        firm['alpha_t'] = results.tvalues['const']
        
        results_dict[f_id] = firm[['beta', 'beta_se', 'beta_t', 'alpha', 'alpha_se', 'alpha_t']]
   
    
    if only_cal == True:
        return results_dict
    
    if results_dict:
        results_df = pd.concat(results_dict)
        return results_df

# %%
result = cal_beta(test_data, 'date', 'permno', 'ret', 'mktrf', '12M', False)
# Out:
# Skipping 10012 due to insufficient data (size: 147)
# Skipping 10089 due to insufficient data (size: 39)
# Skipping 10108 due to insufficient data (size: 154)
# Skipping 10453 due to insufficient data (size: 166)
# Skipping 10691 due to insufficient data (size: 82)
# Skipping 10906 due to insufficient data (size: 40)
# Skipping 10935 due to insufficient data (size: 165)
# Skipping 11216 due to insufficient data (size: 168)
# Skipping 11262 due to insufficient data (size: 79)
# Skipping 11358 due to insufficient data (size: 167)
# Skipping 11371 due to insufficient data (size: 19)
# Skipping 11393 due to insufficient data (size: 168)
# Skipping 11473 due to insufficient data (size: 121)
# Skipping 11483 due to insufficient data (size: 73)
# Skipping 11485 due to insufficient data (size: 61)
# Skipping 11643 due to insufficient data (size: 54)
# Skipping 11646 due to insufficient data (size: 39)
# Skipping 11794 due to insufficient data (size: 133)
# Skipping 11803 due to insufficient data (size: 118)
# Skipping 11851 due to insufficient data (size: 90)
# Skipping 11901 due to insufficient data (size: 31)
# Skipping 12107 due to insufficient data (size: 180)
# Skipping 12174 due to insufficient data (size: 47)
# Skipping 12177 due to insufficient data (size: 117)
# Skipping 12265 due to insufficient data (size: 102)
# Skipping 12311 due to insufficient data (size: 137)
# Skipping 12346 due to insufficient data (size: 36)
# Skipping 12396 due to insufficient data (size: 197)
# Skipping 12485 due to insufficient data (size: 51)
# Skipping 12544 due to insufficient data (size: 27)
# Skipping 12591 due to insufficient data (size: 191)
# Skipping 12593 due to insufficient data (size: 192)
# Skipping 12594 due to insufficient data (size: 196)
# Skipping 12595 due to insufficient data (size: 196)
# Skipping 12596 due to insufficient data (size: 196)
# Skipping 12600 due to insufficient data (size: 191)
# Skipping 12601 due to insufficient data (size: 191)
# Skipping 12602 due to insufficient data (size: 191)
# Skipping 12603 due to insufficient data (size: 191)
# Skipping 12604 due to insufficient data (size: 191)
# Skipping 12605 due to insufficient data (size: 191)
# Skipping 12606 due to insufficient data (size: 191)
# Skipping 12607 due to insufficient data (size: 191)
# Skipping 12608 due to insufficient data (size: 191)
# Skipping 12609 due to insufficient data (size: 191)
# Skipping 12610 due to insufficient data (size: 191)
# Skipping 12611 due to insufficient data (size: 191)
# Skipping 12612 due to insufficient data (size: 191)
# Skipping 12613 due to insufficient data (size: 191)
# Skipping 12614 due to insufficient data (size: 191)
# Skipping 12615 due to insufficient data (size: 196)
# Skipping 12623 due to insufficient data (size: 190)
# Skipping 12624 due to insufficient data (size: 197)
# Skipping 12625 due to insufficient data (size: 190)
# Skipping 12627 due to insufficient data (size: 161)
# Skipping 12628 due to insufficient data (size: 190)
# Skipping 12632 due to insufficient data (size: 192)
# Skipping 12633 due to insufficient data (size: 197)
# Skipping 12636 due to insufficient data (size: 191)
# Skipping 12640 due to insufficient data (size: 194)
# Skipping 12641 due to insufficient data (size: 177)
# Skipping 12644 due to insufficient data (size: 184)
# Skipping 12645 due to insufficient data (size: 179)
# Skipping 12646 due to insufficient data (size: 177)
# Skipping 12647 due to insufficient data (size: 177)
# Skipping 12648 due to insufficient data (size: 177)
# Skipping 12649 due to insufficient data (size: 177)
# Skipping 12651 due to insufficient data (size: 177)
# Skipping 12652 due to insufficient data (size: 177)
# Skipping 12653 due to insufficient data (size: 177)
# Skipping 12654 due to insufficient data (size: 177)
# Skipping 12655 due to insufficient data (size: 177)
# Skipping 12656 due to insufficient data (size: 176)
# Skipping 12657 due to insufficient data (size: 176)
# Skipping 12658 due to insufficient data (size: 176)
# Skipping 12659 due to insufficient data (size: 176)
# Skipping 12660 due to insufficient data (size: 189)
# Skipping 12661 due to insufficient data (size: 181)
# Skipping 12662 due to insufficient data (size: 172)
# Skipping 12663 due to insufficient data (size: 172)
# Skipping 12664 due to insufficient data (size: 187)
# Skipping 12665 due to insufficient data (size: 180)
# Skipping 12666 due to insufficient data (size: 173)
# Skipping 12667 due to insufficient data (size: 184)
# Skipping 12668 due to insufficient data (size: 189)
# Skipping 12671 due to insufficient data (size: 187)
# Skipping 12672 due to insufficient data (size: 187)
# Skipping 12673 due to insufficient data (size: 180)
# Skipping 12674 due to insufficient data (size: 180)
# Skipping 12675 due to insufficient data (size: 185)
# Skipping 12676 due to insufficient data (size: 180)
# Skipping 12679 due to insufficient data (size: 185)
# Skipping 12680 due to insufficient data (size: 179)
# Skipping 12681 due to insufficient data (size: 179)
# Skipping 12682 due to insufficient data (size: 180)
# Skipping 12683 due to insufficient data (size: 176)
# Skipping 12684 due to insufficient data (size: 180)
# Skipping 12687 due to insufficient data (size: 180)
# Skipping 12688 due to insufficient data (size: 171)
# Skipping 12689 due to insufficient data (size: 184)
# Skipping 12690 due to insufficient data (size: 171)
# Skipping 12691 due to insufficient data (size: 175)
# Skipping 12692 due to insufficient data (size: 176)
# Skipping 12693 due to insufficient data (size: 184)
# Skipping 12695 due to insufficient data (size: 176)
# Skipping 12696 due to insufficient data (size: 180)
# Skipping 12697 due to insufficient data (size: 178)
# Skipping 12698 due to insufficient data (size: 188)
# Skipping 12699 due to insufficient data (size: 175)
# Skipping 12700 due to insufficient data (size: 180)
# Skipping 12718 due to insufficient data (size: 189)
# Skipping 12719 due to insufficient data (size: 152)
# Skipping 12720 due to insufficient data (size: 161)
# Skipping 12725 due to insufficient data (size: 152)
# Skipping 12726 due to insufficient data (size: 152)
# Skipping 12727 due to insufficient data (size: 152)
# Skipping 12728 due to insufficient data (size: 152)
# Skipping 12729 due to insufficient data (size: 161)
# Skipping 12732 due to insufficient data (size: 151)
# Skipping 12733 due to insufficient data (size: 166)
# Skipping 12734 due to insufficient data (size: 156)
# Skipping 12735 due to insufficient data (size: 168)
# Skipping 12736 due to insufficient data (size: 167)
# Skipping 12737 due to insufficient data (size: 153)
# Skipping 12738 due to insufficient data (size: 166)
# Skipping 12739 due to insufficient data (size: 155)
# Skipping 12740 due to insufficient data (size: 155)
# Skipping 12741 due to insufficient data (size: 151)
# Skipping 12742 due to insufficient data (size: 156)
# Skipping 12743 due to insufficient data (size: 151)
# Skipping 12744 due to insufficient data (size: 161)
# Skipping 12745 due to insufficient data (size: 161)
# Skipping 12746 due to insufficient data (size: 166)
# Skipping 12747 due to insufficient data (size: 155)
# Skipping 12748 due to insufficient data (size: 151)
# Skipping 12751 due to insufficient data (size: 161)
# Skipping 12752 due to insufficient data (size: 151)
# Skipping 12753 due to insufficient data (size: 166)
# Skipping 12754 due to insufficient data (size: 166)
# Skipping 12755 due to insufficient data (size: 154)
# Skipping 12756 due to insufficient data (size: 162)
# Skipping 12759 due to insufficient data (size: 167)
# Skipping 12760 due to insufficient data (size: 164)
# Skipping 12761 due to insufficient data (size: 150)
# Skipping 12762 due to insufficient data (size: 150)
# Skipping 12763 due to insufficient data (size: 150)
# Skipping 12764 due to insufficient data (size: 150)
# Skipping 12767 due to insufficient data (size: 150)
# Skipping 12768 due to insufficient data (size: 150)
# Skipping 12769 due to insufficient data (size: 150)
# Skipping 12770 due to insufficient data (size: 150)
# Skipping 12771 due to insufficient data (size: 150)
# Skipping 12772 due to insufficient data (size: 149)
# Skipping 12775 due to insufficient data (size: 156)
# Skipping 12776 due to insufficient data (size: 156)
# Skipping 12777 due to insufficient data (size: 156)
# Skipping 12778 due to insufficient data (size: 156)
# Skipping 12779 due to insufficient data (size: 156)
# Skipping 12780 due to insufficient data (size: 156)
# Skipping 12782 due to insufficient data (size: 151)
# Skipping 12783 due to insufficient data (size: 166)
# Skipping 12784 due to insufficient data (size: 159)
# Skipping 12785 due to insufficient data (size: 169)
# Skipping 12786 due to insufficient data (size: 166)
# Skipping 12787 due to insufficient data (size: 151)
# Skipping 12788 due to insufficient data (size: 162)
# Skipping 12789 due to insufficient data (size: 156)
# Skipping 12791 due to insufficient data (size: 162)
# Skipping 12792 due to insufficient data (size: 122)
# Skipping 12793 due to insufficient data (size: 162)
# Skipping 12794 due to insufficient data (size: 152)
# Skipping 12795 due to insufficient data (size: 167)
# Skipping 12796 due to insufficient data (size: 151)
# Skipping 12797 due to insufficient data (size: 150)
# Skipping 12798 due to insufficient data (size: 167)
# Skipping 12799 due to insufficient data (size: 153)
# Skipping 12826 due to insufficient data (size: 163)
# Skipping 12827 due to insufficient data (size: 152)
# Skipping 12828 due to insufficient data (size: 127)
# Skipping 12831 due to insufficient data (size: 132)
# Skipping 12832 due to insufficient data (size: 134)
# Skipping 12833 due to insufficient data (size: 134)
# Skipping 12834 due to insufficient data (size: 134)
# Skipping 12835 due to insufficient data (size: 136)
# Skipping 12836 due to insufficient data (size: 143)
# Skipping 12839 due to insufficient data (size: 141)
# Skipping 12840 due to insufficient data (size: 141)
# Skipping 12841 due to insufficient data (size: 142)
# Skipping 12842 due to insufficient data (size: 142)
# Skipping 12843 due to insufficient data (size: 142)
# Skipping 12844 due to insufficient data (size: 142)
# Skipping 12847 due to insufficient data (size: 142)
# Skipping 12848 due to insufficient data (size: 138)
# Skipping 12849 due to insufficient data (size: 138)
# Skipping 12850 due to insufficient data (size: 138)
# Skipping 12851 due to insufficient data (size: 138)
# Skipping 12852 due to insufficient data (size: 138)
# Skipping 12855 due to insufficient data (size: 132)
# Skipping 12856 due to insufficient data (size: 132)
# Skipping 12857 due to insufficient data (size: 132)
# Skipping 12858 due to insufficient data (size: 132)
# Skipping 12859 due to insufficient data (size: 132)
# Skipping 12860 due to insufficient data (size: 132)
# Skipping 12863 due to insufficient data (size: 132)
# Skipping 12864 due to insufficient data (size: 132)
# Skipping 12865 due to insufficient data (size: 142)
# Skipping 12866 due to insufficient data (size: 147)
# Skipping 12867 due to insufficient data (size: 142)
# Skipping 12868 due to insufficient data (size: 139)
# Skipping 12869 due to insufficient data (size: 143)
# Skipping 12870 due to insufficient data (size: 136)
# Skipping 12871 due to insufficient data (size: 138)
# Skipping 12872 due to insufficient data (size: 126)
# Skipping 12873 due to insufficient data (size: 138)
# Skipping 12874 due to insufficient data (size: 136)
# Skipping 12875 due to insufficient data (size: 137)
# Skipping 12876 due to insufficient data (size: 137)
# Skipping 12877 due to insufficient data (size: 132)
# Skipping 12878 due to insufficient data (size: 142)
# Skipping 12879 due to insufficient data (size: 133)
# Skipping 12880 due to insufficient data (size: 126)
# Skipping 12881 due to insufficient data (size: 130)
# Skipping 12882 due to insufficient data (size: 128)
# Skipping 12883 due to insufficient data (size: 127)
# Skipping 12884 due to insufficient data (size: 127)
# Skipping 12885 due to insufficient data (size: 134)
# Skipping 12886 due to insufficient data (size: 147)
# Skipping 12887 due to insufficient data (size: 131)
# Skipping 12890 due to insufficient data (size: 138)
# Skipping 12891 due to insufficient data (size: 148)
# Skipping 12892 due to insufficient data (size: 109)
# Skipping 12893 due to insufficient data (size: 112)
# Skipping 12894 due to insufficient data (size: 107)
# Skipping 12895 due to insufficient data (size: 109)
# Skipping 12898 due to insufficient data (size: 119)
# Skipping 12899 due to insufficient data (size: 119)
# Skipping 12900 due to insufficient data (size: 118)
# Skipping 12901 due to insufficient data (size: 119)
# Skipping 12902 due to insufficient data (size: 118)
# Skipping 12903 due to insufficient data (size: 114)
# Skipping 12904 due to insufficient data (size: 118)
# Skipping 12905 due to insufficient data (size: 113)
# Skipping 12906 due to insufficient data (size: 109)
# Skipping 12907 due to insufficient data (size: 108)
# Skipping 12908 due to insufficient data (size: 108)
# Skipping 12911 due to insufficient data (size: 118)
# Skipping 12912 due to insufficient data (size: 111)
# Skipping 12913 due to insufficient data (size: 108)
# Skipping 12914 due to insufficient data (size: 109)
# Skipping 12915 due to insufficient data (size: 112)
# Skipping 12916 due to insufficient data (size: 124)
# Skipping 12919 due to insufficient data (size: 108)
# Skipping 12920 due to insufficient data (size: 122)
# Skipping 12921 due to insufficient data (size: 123)
# Skipping 12922 due to insufficient data (size: 114)
# Skipping 12923 due to insufficient data (size: 124)
# Skipping 12924 due to insufficient data (size: 109)
# Skipping 12927 due to insufficient data (size: 114)
# Skipping 12946 due to insufficient data (size: 87)
# Skipping 12947 due to insufficient data (size: 103)
# Skipping 12948 due to insufficient data (size: 99)
# Skipping 12949 due to insufficient data (size: 93)
# Skipping 12950 due to insufficient data (size: 93)
# Skipping 12951 due to insufficient data (size: 93)
# Skipping 12952 due to insufficient data (size: 106)
# Skipping 12953 due to insufficient data (size: 94)
# Skipping 12954 due to insufficient data (size: 96)
# Skipping 12955 due to insufficient data (size: 103)
# Skipping 12956 due to insufficient data (size: 103)
# Skipping 12957 due to insufficient data (size: 98)
# Skipping 12959 due to insufficient data (size: 104)
# Skipping 12960 due to insufficient data (size: 98)
# Skipping 12961 due to insufficient data (size: 91)
# Skipping 12962 due to insufficient data (size: 77)
# Skipping 12963 due to insufficient data (size: 95)
# Skipping 12964 due to insufficient data (size: 104)
# Skipping 12965 due to insufficient data (size: 103)
# Skipping 12966 due to insufficient data (size: 86)
# Skipping 12967 due to insufficient data (size: 93)
# Skipping 12970 due to insufficient data (size: 94)
# Skipping 12971 due to insufficient data (size: 97)
# Skipping 12972 due to insufficient data (size: 100)
# Skipping 12973 due to insufficient data (size: 69)
# Skipping 12974 due to insufficient data (size: 65)
# Skipping 12975 due to insufficient data (size: 69)
# Skipping 12978 due to insufficient data (size: 69)
# Skipping 12979 due to insufficient data (size: 69)
# Skipping 12980 due to insufficient data (size: 69)
# Skipping 12981 due to insufficient data (size: 61)
# Skipping 12982 due to insufficient data (size: 71)
# Skipping 12983 due to insufficient data (size: 80)
# Skipping 12986 due to insufficient data (size: 76)
# Skipping 12987 due to insufficient data (size: 76)
# Skipping 12988 due to insufficient data (size: 80)
# Skipping 12989 due to insufficient data (size: 80)
# Skipping 12990 due to insufficient data (size: 80)
# Skipping 12991 due to insufficient data (size: 76)
# Skipping 12994 due to insufficient data (size: 79)
# Skipping 12995 due to insufficient data (size: 68)
# Skipping 12996 due to insufficient data (size: 74)
# Skipping 12997 due to insufficient data (size: 64)
# Skipping 12998 due to insufficient data (size: 64)
# Skipping 12999 due to insufficient data (size: 64)
# Skipping 13000 due to insufficient data (size: 72)
# Skipping 13001 due to insufficient data (size: 72)
# Skipping 13002 due to insufficient data (size: 72)
# Skipping 13003 due to insufficient data (size: 80)
# Skipping 13006 due to insufficient data (size: 74)
# Skipping 13007 due to insufficient data (size: 79)
# Skipping 13008 due to insufficient data (size: 67)
# Skipping 13009 due to insufficient data (size: 67)
# Skipping 13010 due to insufficient data (size: 44)
# Skipping 13011 due to insufficient data (size: 44)
# Skipping 13013 due to insufficient data (size: 59)
# Skipping 13014 due to insufficient data (size: 76)
# Skipping 13015 due to insufficient data (size: 81)
# Skipping 13016 due to insufficient data (size: 60)
# Skipping 13017 due to insufficient data (size: 61)
# Skipping 13018 due to insufficient data (size: 41)
# Skipping 13019 due to insufficient data (size: 42)
# Skipping 13022 due to insufficient data (size: 44)
# Skipping 13023 due to insufficient data (size: 49)
# Skipping 13024 due to insufficient data (size: 49)
# Skipping 13025 due to insufficient data (size: 49)
# Skipping 13026 due to insufficient data (size: 49)
# Skipping 13027 due to insufficient data (size: 49)
# Skipping 13028 due to insufficient data (size: 55)
# Skipping 13029 due to insufficient data (size: 61)
# Skipping 13030 due to insufficient data (size: 61)
# Skipping 13031 due to insufficient data (size: 59)
# Skipping 13032 due to insufficient data (size: 59)
# Skipping 13033 due to insufficient data (size: 49)
# Skipping 13034 due to insufficient data (size: 44)
# Skipping 13035 due to insufficient data (size: 41)
# Skipping 13036 due to insufficient data (size: 55)
# Skipping 13037 due to insufficient data (size: 60)
# Skipping 13038 due to insufficient data (size: 44)
# Skipping 13041 due to insufficient data (size: 41)
# Skipping 13042 due to insufficient data (size: 60)
# Skipping 13043 due to insufficient data (size: 60)
# Skipping 13044 due to insufficient data (size: 60)
# Skipping 13045 due to insufficient data (size: 60)
# Skipping 13046 due to insufficient data (size: 53)
# Skipping 13049 due to insufficient data (size: 50)
# Skipping 13076 due to insufficient data (size: 25)
# Skipping 13077 due to insufficient data (size: 33)
# Skipping 13078 due to insufficient data (size: 28)
# Skipping 13079 due to insufficient data (size: 39)
# Skipping 13080 due to insufficient data (size: 35)
# Skipping 13081 due to insufficient data (size: 30)
# Skipping 13082 due to insufficient data (size: 29)
# Skipping 13083 due to insufficient data (size: 33)
# Skipping 13084 due to insufficient data (size: 28)
# Skipping 13085 due to insufficient data (size: 26)
# Skipping 13086 due to insufficient data (size: 41)
# Skipping 13087 due to insufficient data (size: 34)
# Skipping 13088 due to insufficient data (size: 34)
# Skipping 13089 due to insufficient data (size: 41)
# Skipping 13090 due to insufficient data (size: 41)
# Skipping 13091 due to insufficient data (size: 41)
# Skipping 13092 due to insufficient data (size: 41)
# Skipping 13093 due to insufficient data (size: 38)
# Skipping 13094 due to insufficient data (size: 39)
# Skipping 13095 due to insufficient data (size: 39)
# Skipping 13096 due to insufficient data (size: 39)
# Skipping 13097 due to insufficient data (size: 38)
# Skipping 13100 due to insufficient data (size: 166)
# Skipping 13102 due to insufficient data (size: 31)
# Skipping 13103 due to insufficient data (size: 29)
# Skipping 13104 due to insufficient data (size: 33)
# Skipping 13105 due to insufficient data (size: 41)
# Skipping 13106 due to insufficient data (size: 29)
# Skipping 13107 due to insufficient data (size: 30)
# Skipping 13108 due to insufficient data (size: 38)
# Skipping 13109 due to insufficient data (size: 28)
# Skipping 13110 due to insufficient data (size: 28)
# Skipping 13111 due to insufficient data (size: 33)
# Skipping 13112 due to insufficient data (size: 31)
# Skipping 13113 due to insufficient data (size: 40)
# Skipping 13114 due to insufficient data (size: 31)
# Skipping 13116 due to insufficient data (size: 10)
# Skipping 13117 due to insufficient data (size: 15)
# Skipping 13118 due to insufficient data (size: 15)
# Skipping 13121 due to insufficient data (size: 18)
# Skipping 13122 due to insufficient data (size: 15)
# Skipping 13123 due to insufficient data (size: 9)
# Skipping 13124 due to insufficient data (size: 10)
# Skipping 13125 due to insufficient data (size: 6)
# Skipping 13126 due to insufficient data (size: 6)
# Skipping 13129 due to insufficient data (size: 6)
# Skipping 13130 due to insufficient data (size: 6)
# Skipping 13131 due to insufficient data (size: 6)
# Skipping 13132 due to insufficient data (size: 6)
# Skipping 13133 due to insufficient data (size: 14)
# Skipping 13137 due to insufficient data (size: 20)
# Skipping 13138 due to insufficient data (size: 20)
# Skipping 13139 due to insufficient data (size: 11)
# Skipping 13140 due to insufficient data (size: 19)
# Skipping 13142 due to insufficient data (size: 10)
# Skipping 13145 due to insufficient data (size: 11)
# Skipping 13159 due to insufficient data (size: 8)
# Skipping 13160 due to insufficient data (size: 12)
# Skipping 13161 due to insufficient data (size: 13)
# Skipping 13162 due to insufficient data (size: 10)
# Skipping 13163 due to insufficient data (size: 14)
# Skipping 13165 due to insufficient data (size: 17)
# Skipping 13166 due to insufficient data (size: 17)
# Skipping 13167 due to insufficient data (size: 20)
# Skipping 13168 due to insufficient data (size: 6)
# Skipping 13169 due to insufficient data (size: 9)
# Skipping 14059 due to insufficient data (size: 174)
# Skipping 14322 due to insufficient data (size: 57)
# Skipping 14891 due to insufficient data (size: 153)
# Skipping 16424 due to insufficient data (size: 189)
# Skipping 16715 due to insufficient data (size: 92)
# Skipping 17337 due to insufficient data (size: 44)
# Skipping 17559 due to insufficient data (size: 144)
# Skipping 22569 due to insufficient data (size: 26)
# Skipping 24572 due to insufficient data (size: 92)
# Skipping 24803 due to insufficient data (size: 34)
# Skipping 25786 due to insufficient data (size: 140)
# Skipping 26060 due to insufficient data (size: 189)
# Skipping 26083 due to insufficient data (size: 137)
# Skipping 26112 due to insufficient data (size: 197)
# Skipping 30307 due to insufficient data (size: 25)
# Skipping 32379 due to insufficient data (size: 126)
# Skipping 34287 due to insufficient data (size: 125)
# Skipping 34463 due to insufficient data (size: 41)
# Skipping 36709 due to insufficient data (size: 94)
# Skipping 38333 due to insufficient data (size: 157)
# Skipping 39773 due to insufficient data (size: 65)
# Skipping 40097 due to insufficient data (size: 44)
# Skipping 43028 due to insufficient data (size: 179)
# Skipping 43692 due to insufficient data (size: 4)
# Skipping 43705 due to insufficient data (size: 4)
# Skipping 44353 due to insufficient data (size: 100)
# Skipping 45110 due to insufficient data (size: 18)
# Skipping 45129 due to insufficient data (size: 126)
# Skipping 45348 due to insufficient data (size: 190)
# Skipping 45744 due to insufficient data (size: 81)
# Skipping 46843 due to insufficient data (size: 163)
# Skipping 48143 due to insufficient data (size: 60)
# Skipping 48696 due to insufficient data (size: 145)
# Skipping 53946 due to insufficient data (size: 176)
# Skipping 54843 due to insufficient data (size: 152)
# Skipping 56354 due to insufficient data (size: 183)
# Skipping 56813 due to insufficient data (size: 72)
# Skipping 56987 due to insufficient data (size: 94)
# Skipping 57066 due to insufficient data (size: 35)
# Skipping 57584 due to insufficient data (size: 34)
# Skipping 57780 due to insufficient data (size: 96)
# Skipping 57884 due to insufficient data (size: 17)
# Skipping 58464 due to insufficient data (size: 168)
# Skipping 61065 due to insufficient data (size: 139)
# Skipping 64004 due to insufficient data (size: 177)
# Skipping 65533 due to insufficient data (size: 78)
# Skipping 65702 due to insufficient data (size: 168)
# Skipping 66369 due to insufficient data (size: 36)
# Skipping 66472 due to insufficient data (size: 20)
# Skipping 66967 due to insufficient data (size: 92)
# Skipping 68065 due to insufficient data (size: 51)
# Skipping 69518 due to insufficient data (size: 121)
# Skipping 69542 due to insufficient data (size: 182)
# Skipping 70156 due to insufficient data (size: 163)
# Skipping 70659 due to insufficient data (size: 93)
# Skipping 71598 due to insufficient data (size: 51)
# Skipping 74580 due to insufficient data (size: 192)
# Skipping 75243 due to insufficient data (size: 38)
# Skipping 75244 due to insufficient data (size: 86)
# Skipping 75264 due to insufficient data (size: 133)
# Skipping 75286 due to insufficient data (size: 49)
# Skipping 75350 due to insufficient data (size: 140)
# Skipping 75351 due to insufficient data (size: 186)
# Skipping 75365 due to insufficient data (size: 194)
# Skipping 75391 due to insufficient data (size: 37)
# Skipping 75393 due to insufficient data (size: 42)
# Skipping 75446 due to insufficient data (size: 145)
# Skipping 75581 due to insufficient data (size: 166)
# Skipping 75609 due to insufficient data (size: 139)
# Skipping 75826 due to insufficient data (size: 149)
# Skipping 75845 due to insufficient data (size: 165)
# Skipping 76101 due to insufficient data (size: 48)
# Skipping 76165 due to insufficient data (size: 183)
# Skipping 76259 due to insufficient data (size: 73)
# Skipping 76299 due to insufficient data (size: 77)
# Skipping 76302 due to insufficient data (size: 155)
# Skipping 76308 due to insufficient data (size: 25)
# Skipping 76443 due to insufficient data (size: 190)
# Skipping 76445 due to insufficient data (size: 125)
# Skipping 76448 due to insufficient data (size: 110)
# Skipping 76513 due to insufficient data (size: 177)
# Skipping 76830 due to insufficient data (size: 41)
# Skipping 76898 due to insufficient data (size: 165)
# Skipping 76937 due to insufficient data (size: 81)
# Skipping 77106 due to insufficient data (size: 100)
# Skipping 77133 due to insufficient data (size: 145)
# Skipping 77155 due to insufficient data (size: 88)
# Skipping 77217 due to insufficient data (size: 110)
# Skipping 77254 due to insufficient data (size: 151)
# Skipping 77284 due to insufficient data (size: 155)
# Skipping 77334 due to insufficient data (size: 15)
# Skipping 77339 due to insufficient data (size: 99)
# Skipping 77427 due to insufficient data (size: 48)
# Skipping 77489 due to insufficient data (size: 82)
# Skipping 77639 due to insufficient data (size: 145)
# Skipping 77839 due to insufficient data (size: 165)
# Skipping 77887 due to insufficient data (size: 167)
# Skipping 78083 due to insufficient data (size: 5)
# Skipping 78236 due to insufficient data (size: 105)
# Skipping 78560 due to insufficient data (size: 151)
# Skipping 78721 due to insufficient data (size: 189)
# Skipping 78752 due to insufficient data (size: 104)
# Skipping 78846 due to insufficient data (size: 146)
# Skipping 78856 due to insufficient data (size: 194)
# Skipping 78867 due to insufficient data (size: 190)
# Skipping 78871 due to insufficient data (size: 31)
# Skipping 78914 due to insufficient data (size: 62)
# Skipping 78956 due to insufficient data (size: 191)
# Skipping 79005 due to insufficient data (size: 198)
# Skipping 79029 due to insufficient data (size: 165)
# Skipping 79087 due to insufficient data (size: 53)
# Skipping 79146 due to insufficient data (size: 65)
# Skipping 79204 due to insufficient data (size: 179)
# Skipping 79339 due to insufficient data (size: 149)
# Skipping 79361 due to insufficient data (size: 194)
# Skipping 79392 due to insufficient data (size: 80)
# Skipping 79420 due to insufficient data (size: 42)
# Skipping 79428 due to insufficient data (size: 114)
# Skipping 79512 due to insufficient data (size: 34)
# Skipping 79591 due to insufficient data (size: 136)
# Skipping 79670 due to insufficient data (size: 123)
# Skipping 79726 due to insufficient data (size: 15)
# Skipping 79742 due to insufficient data (size: 39)
# Skipping 79801 due to insufficient data (size: 189)
# Skipping 79845 due to insufficient data (size: 192)
# Skipping 79910 due to insufficient data (size: 108)
# Skipping 79944 due to insufficient data (size: 152)
# Skipping 79950 due to insufficient data (size: 110)
# Skipping 79971 due to insufficient data (size: 186)
# Skipping 80055 due to insufficient data (size: 126)
# Skipping 80122 due to insufficient data (size: 95)
# Skipping 80173 due to insufficient data (size: 117)
# Skipping 80178 due to insufficient data (size: 189)
# Skipping 80212 due to insufficient data (size: 39)
# Skipping 80290 due to insufficient data (size: 4)
# Skipping 80345 due to insufficient data (size: 184)
# Skipping 80359 due to insufficient data (size: 70)
# Skipping 80629 due to insufficient data (size: 189)
# Skipping 80713 due to insufficient data (size: 90)
# Skipping 80730 due to insufficient data (size: 131)
# Skipping 80778 due to insufficient data (size: 185)
# Skipping 80852 due to insufficient data (size: 22)
# Skipping 80946 due to insufficient data (size: 97)
# Skipping 80958 due to insufficient data (size: 103)
# Skipping 81002 due to insufficient data (size: 121)
# Skipping 81020 due to insufficient data (size: 125)
# Skipping 81060 due to insufficient data (size: 179)
# Skipping 81098 due to insufficient data (size: 152)
# Skipping 81125 due to insufficient data (size: 145)
# Skipping 81185 due to insufficient data (size: 80)
# Skipping 81214 due to insufficient data (size: 4)
# Skipping 81233 due to insufficient data (size: 167)
# Skipping 81244 due to insufficient data (size: 183)
# Skipping 81290 due to insufficient data (size: 55)
# Skipping 81483 due to insufficient data (size: 128)
# Skipping 81510 due to insufficient data (size: 152)
# Skipping 81590 due to insufficient data (size: 35)
# Skipping 81601 due to insufficient data (size: 130)
# Skipping 81636 due to insufficient data (size: 189)
# Skipping 81672 due to insufficient data (size: 14)
# Skipping 81709 due to insufficient data (size: 19)
# Skipping 81710 due to insufficient data (size: 103)
# Skipping 81726 due to insufficient data (size: 115)
# Skipping 81865 due to insufficient data (size: 41)
# Skipping 81904 due to insufficient data (size: 24)
# Skipping 82236 due to insufficient data (size: 157)
# Skipping 82294 due to insufficient data (size: 14)
# Skipping 82478 due to insufficient data (size: 23)
# Skipping 82511 due to insufficient data (size: 187)
# Skipping 82549 due to insufficient data (size: 67)
# Skipping 82680 due to insufficient data (size: 97)
# Skipping 82681 due to insufficient data (size: 130)
# Skipping 82724 due to insufficient data (size: 61)
# Skipping 82767 due to insufficient data (size: 136)
# Skipping 82805 due to insufficient data (size: 129)
# Skipping 83163 due to insufficient data (size: 97)
# Skipping 83236 due to insufficient data (size: 5)
# Skipping 83295 due to insufficient data (size: 7)
# Skipping 83334 due to insufficient data (size: 25)
# Skipping 83404 due to insufficient data (size: 145)
# Skipping 83444 due to insufficient data (size: 61)
# Skipping 83455 due to insufficient data (size: 93)
# Skipping 83456 due to insufficient data (size: 100)
# Skipping 83478 due to insufficient data (size: 125)
# Skipping 83496 due to insufficient data (size: 134)
# Skipping 83581 due to insufficient data (size: 145)
# Skipping 83590 due to insufficient data (size: 96)
# Skipping 83650 due to insufficient data (size: 77)
# Skipping 83657 due to insufficient data (size: 121)
# Skipping 83764 due to insufficient data (size: 38)
# Skipping 83813 due to insufficient data (size: 90)
# Skipping 83918 due to insufficient data (size: 72)
# Skipping 83926 due to insufficient data (size: 147)
# Skipping 83967 due to insufficient data (size: 106)
# Skipping 84133 due to insufficient data (size: 18)
# Skipping 84136 due to insufficient data (size: 143)
# Skipping 84193 due to insufficient data (size: 147)
# Skipping 84211 due to insufficient data (size: 97)
# Skipping 84223 due to insufficient data (size: 159)
# Skipping 84229 due to insufficient data (size: 146)
# Skipping 84232 due to insufficient data (size: 183)
# Skipping 84240 due to insufficient data (size: 11)
# Skipping 84307 due to insufficient data (size: 158)
# Skipping 84369 due to insufficient data (size: 65)
# Skipping 84431 due to insufficient data (size: 67)
# Skipping 84508 due to insufficient data (size: 21)
# Skipping 84525 due to insufficient data (size: 105)
# Skipping 84536 due to insufficient data (size: 47)
# Skipping 84605 due to insufficient data (size: 9)
# Skipping 84629 due to insufficient data (size: 181)
# Skipping 84650 due to insufficient data (size: 170)
# Skipping 84659 due to insufficient data (size: 62)
# Skipping 84666 due to insufficient data (size: 173)
# Skipping 85005 due to insufficient data (size: 93)
# Skipping 85057 due to insufficient data (size: 80)
# Skipping 85073 due to insufficient data (size: 189)
# Skipping 85197 due to insufficient data (size: 38)
# Skipping 85202 due to insufficient data (size: 29)
# Skipping 85210 due to insufficient data (size: 3)
# Skipping 85267 due to insufficient data (size: 135)
# Skipping 85304 due to insufficient data (size: 4)
# Skipping 85358 due to insufficient data (size: 192)
# Skipping 85431 due to insufficient data (size: 23)
# Skipping 85458 due to insufficient data (size: 108)
# Skipping 85463 due to insufficient data (size: 132)
# Skipping 85495 due to insufficient data (size: 199)
# Skipping 85620 due to insufficient data (size: 67)
# Skipping 85624 due to insufficient data (size: 126)
# Skipping 85740 due to insufficient data (size: 5)
# Skipping 85816 due to insufficient data (size: 133)
# Skipping 85817 due to insufficient data (size: 43)
# Skipping 85874 due to insufficient data (size: 165)
# Skipping 85890 due to insufficient data (size: 184)
# Skipping 85933 due to insufficient data (size: 72)
# Skipping 85950 due to insufficient data (size: 96)
# Skipping 86037 due to insufficient data (size: 44)
# Skipping 86063 due to insufficient data (size: 69)
# Skipping 86156 due to insufficient data (size: 60)
# Skipping 86194 due to insufficient data (size: 186)
# Skipping 86215 due to insufficient data (size: 86)
# Skipping 86224 due to insufficient data (size: 98)
# Skipping 86248 due to insufficient data (size: 145)
# Skipping 86259 due to insufficient data (size: 194)
# Skipping 86268 due to insufficient data (size: 10)
# Skipping 86293 due to insufficient data (size: 125)
# Skipping 86401 due to insufficient data (size: 54)
# Skipping 86447 due to insufficient data (size: 112)
# Skipping 86579 due to insufficient data (size: 14)
# Skipping 86591 due to insufficient data (size: 195)
# Skipping 86748 due to insufficient data (size: 194)
# Skipping 86758 due to insufficient data (size: 106)
# Skipping 86761 due to insufficient data (size: 103)
# Skipping 86770 due to insufficient data (size: 25)
# Skipping 86813 due to insufficient data (size: 159)
# Skipping 86885 due to insufficient data (size: 104)
# Skipping 86913 due to insufficient data (size: 123)
# Skipping 86917 due to insufficient data (size: 103)
# Skipping 87030 due to insufficient data (size: 128)
# Skipping 87060 due to insufficient data (size: 114)
# Skipping 87079 due to insufficient data (size: 148)
# Skipping 87085 due to insufficient data (size: 169)
# Skipping 87087 due to insufficient data (size: 128)
# Skipping 87093 due to insufficient data (size: 178)
# Skipping 87095 due to insufficient data (size: 23)
# Skipping 87100 due to insufficient data (size: 137)
# Skipping 87147 due to insufficient data (size: 180)
# Skipping 87227 due to insufficient data (size: 55)
# Skipping 87228 due to insufficient data (size: 188)
# Skipping 87241 due to insufficient data (size: 199)
# Skipping 87248 due to insufficient data (size: 31)
# Skipping 87281 due to insufficient data (size: 193)
# Skipping 87283 due to insufficient data (size: 193)
# Skipping 87293 due to insufficient data (size: 94)
# Skipping 87385 due to insufficient data (size: 87)
# Skipping 87387 due to insufficient data (size: 38)
# Skipping 87401 due to insufficient data (size: 63)
# Skipping 87412 due to insufficient data (size: 68)
# Skipping 87425 due to insufficient data (size: 135)
# Skipping 87435 due to insufficient data (size: 111)
# Skipping 87465 due to insufficient data (size: 37)
# Skipping 87472 due to insufficient data (size: 185)
# Skipping 87621 due to insufficient data (size: 145)
# Skipping 87642 due to insufficient data (size: 155)
# Skipping 87795 due to insufficient data (size: 20)
# Skipping 87826 due to insufficient data (size: 137)
# Skipping 87828 due to insufficient data (size: 123)
# Skipping 87839 due to insufficient data (size: 83)
# Skipping 88156 due to insufficient data (size: 24)
# Skipping 88158 due to insufficient data (size: 189)
# Skipping 88180 due to insufficient data (size: 179)
# Skipping 88187 due to insufficient data (size: 108)
# Skipping 88198 due to insufficient data (size: 164)
# Skipping 88256 due to insufficient data (size: 125)
# Skipping 88270 due to insufficient data (size: 80)
# Skipping 88273 due to insufficient data (size: 170)
# Skipping 88275 due to insufficient data (size: 179)
# Skipping 88305 due to insufficient data (size: 73)
# Skipping 88393 due to insufficient data (size: 119)
# Skipping 88418 due to insufficient data (size: 129)
# Skipping 88425 due to insufficient data (size: 92)
# Skipping 88431 due to insufficient data (size: 50)
# Skipping 88441 due to insufficient data (size: 76)
# Skipping 88460 due to insufficient data (size: 125)
# Skipping 88500 due to insufficient data (size: 95)
# Skipping 88527 due to insufficient data (size: 193)
# Skipping 88578 due to insufficient data (size: 176)
# Skipping 88585 due to insufficient data (size: 118)
# Skipping 88622 due to insufficient data (size: 114)
# Skipping 88625 due to insufficient data (size: 168)
# Skipping 88631 due to insufficient data (size: 2)
# Skipping 88651 due to insufficient data (size: 62)
# Skipping 88737 due to insufficient data (size: 67)
# Skipping 88749 due to insufficient data (size: 14)
# Skipping 88785 due to insufficient data (size: 137)
# Skipping 88802 due to insufficient data (size: 53)
# Skipping 88846 due to insufficient data (size: 199)
# Skipping 88866 due to insufficient data (size: 125)
# Skipping 88907 due to insufficient data (size: 95)
# Skipping 88938 due to insufficient data (size: 13)
# Skipping 88952 due to insufficient data (size: 66)
# Skipping 88972 due to insufficient data (size: 37)
# Skipping 89005 due to insufficient data (size: 125)
# Skipping 89032 due to insufficient data (size: 57)
# Skipping 89104 due to insufficient data (size: 62)
# Skipping 89132 due to insufficient data (size: 150)
# Skipping 89133 due to insufficient data (size: 176)
# Skipping 89223 due to insufficient data (size: 99)
# Skipping 89239 due to insufficient data (size: 48)
# Skipping 89259 due to insufficient data (size: 158)
# Skipping 89260 due to insufficient data (size: 121)
# Skipping 89276 due to insufficient data (size: 90)
# Skipping 89306 due to insufficient data (size: 144)
# Skipping 89354 due to insufficient data (size: 120)
# Skipping 89374 due to insufficient data (size: 167)
# Skipping 89388 due to insufficient data (size: 157)
# Skipping 89389 due to insufficient data (size: 142)
# Skipping 89396 due to insufficient data (size: 168)
# Skipping 89400 due to insufficient data (size: 102)
# Skipping 89414 due to insufficient data (size: 86)
# Skipping 89423 due to insufficient data (size: 36)
# Skipping 89448 due to insufficient data (size: 12)
# Skipping 89457 due to insufficient data (size: 140)
# Skipping 89559 due to insufficient data (size: 143)
# Skipping 89569 due to insufficient data (size: 63)
# Skipping 89639 due to insufficient data (size: 121)
# Skipping 89640 due to insufficient data (size: 72)
# Skipping 89706 due to insufficient data (size: 137)
# Skipping 89794 due to insufficient data (size: 33)
# Skipping 89829 due to insufficient data (size: 157)
# Skipping 89871 due to insufficient data (size: 150)
# Skipping 89884 due to insufficient data (size: 150)
# Skipping 89890 due to insufficient data (size: 195)
# Skipping 89929 due to insufficient data (size: 42)
# Skipping 89957 due to insufficient data (size: 72)
# Skipping 89963 due to insufficient data (size: 72)
# Skipping 90021 due to insufficient data (size: 122)
# Skipping 90167 due to insufficient data (size: 95)
# Skipping 90420 due to insufficient data (size: 166)
# Skipping 90667 due to insufficient data (size: 126)
# Skipping 90712 due to insufficient data (size: 99)
# Skipping 90721 due to insufficient data (size: 134)
# Skipping 90848 due to insufficient data (size: 44)
# Skipping 91140 due to insufficient data (size: 165)
# Skipping 91150 due to insufficient data (size: 156)
# Skipping 91180 due to insufficient data (size: 131)
# Skipping 91323 due to insufficient data (size: 145)
# Skipping 91388 due to insufficient data (size: 171)
# Skipping 91738 due to insufficient data (size: 191)
# Skipping 91842 due to insufficient data (size: 175)
# Skipping 91846 due to insufficient data (size: 175)
# Skipping 92113 due to insufficient data (size: 161)
# Skipping 92114 due to insufficient data (size: 164)
# Skipping 92117 due to insufficient data (size: 162)
# Skipping 92194 due to insufficient data (size: 185)
# Skipping 92225 due to insufficient data (size: 197)
# Skipping 92595 due to insufficient data (size: 133)
# Skipping 92649 due to insufficient data (size: 183)
# Skipping 92650 due to insufficient data (size: 183)
# Skipping 92651 due to insufficient data (size: 188)
# Skipping 92652 due to insufficient data (size: 188)
# Skipping 92653 due to insufficient data (size: 178)
# Skipping 92654 due to insufficient data (size: 183)
# Skipping 92656 due to insufficient data (size: 188)
# Skipping 92657 due to insufficient data (size: 178)
# Skipping 92698 due to insufficient data (size: 160)
# Skipping 92715 due to insufficient data (size: 93)
# Skipping 92798 due to insufficient data (size: 106)
# Skipping 92799 due to insufficient data (size: 47)
# Skipping 92838 due to insufficient data (size: 55)
# Skipping 92853 due to insufficient data (size: 154)
# Skipping 93241 due to insufficient data (size: 193)
# Skipping 93242 due to insufficient data (size: 193)
# Skipping 93250 due to insufficient data (size: 163)
# Skipping 93326 due to insufficient data (size: 127)
# Skipping 93327 due to insufficient data (size: 127)
# Skipping 93328 due to insufficient data (size: 127)
# Skipping 93348 due to insufficient data (size: 197)
# Skipping 93405 due to insufficient data (size: 193)

# %%
result
# Out:
#                     beta   beta_se     beta_t     alpha  alpha_se   alpha_t
# 10001 5182           NaN       NaN        NaN       NaN       NaN       NaN
#       5183           NaN       NaN        NaN       NaN       NaN       NaN
#       5184           NaN       NaN        NaN       NaN       NaN       NaN
#       5185           NaN       NaN        NaN       NaN       NaN       NaN
#       5186           NaN       NaN        NaN       NaN       NaN       NaN
# ...                  ...       ...        ...       ...       ...       ...
# 93436 81943088  1.165372  0.109342  10.658055  0.000528  0.001661  0.318069
#       81943089  1.165558  0.109162  10.677312  0.000488  0.001658  0.294279
#       81943090  1.161237  0.108332  10.719208  0.000352  0.001648  0.213315
#       81943091  1.159306  0.107633  10.770895  0.000503  0.001639  0.306704
#       81943092  1.159540  0.107610  10.775420  0.000474  0.001639  0.288929
#
# [11801483 rows x 6 columns]

# %% [markdown]
# #### Scholes and Williams (1977)'s beta

# %% [markdown]
# Scholes and Williams (1977) present evidence that non-synchronous trading can affect empirical estimates of beta using the standard CAPM model.
#
# To account for nonsynchronous trading, they suggest:
#
# $$ r_{i,t} = \alpha_i + \beta_{i}^{-} MKT_{t-1} + e_{i,t}^{-}$$
# $$ r_{i,t} = \alpha_i + \beta_{i} MKT_{t-1} + e_{i,t}$$
# $$r_{i,t} = \alpha_i + \beta_{i}^{+} MKT_{t-1} + e_{i,t}^{+}$$
# and define beta as
# $$ \beta_{i}^{SW} = \frac{\hat{b}_{i}^{-} + \hat{b}_{i} + \hat{b}_{i}^{+}}{1 + 2 \rho}$$
#
# where $\rho$ is the first-order serial correlation of the market porfolio's excess returns, and $\hat{b}_{i}^{-}$, $\hat{b}_{i}$, and $\hat{b}_{i}^{+}$ are the estimated slope coefficients from regression models.

# %% [markdown]
# For Scholes and Williams (1977), beta is best implemented using daily stock return data because monthly return data are less affected by problems caused by non-synchronous trading.
#
# In this chapter, we use length of sample to calculate Scholes and Williams (1997) as 1 year __daily data__.

# %%
def cal_beta_sw(data, date, id, ret, mkt, period, dataframe=False):
    """
    Calculate Scholes and Williams adjusted beta, its t-value, and corresponding alpha with its t-value.
    
    Parameters:
    data (pd.DataFrame): The dataset containing the required columns.
    date (str): The date column in the dataset.
    id (str): The column representing the unique identifier for each asset (e.g., stock ID).
    ret (str): The column representing the asset's returns.
    mkt (str): The column representing the market's returns.
    period (str): The rolling window period. Choose from '1M', '3M', '6M', '12M', '24M'.
    dataframe (bool): Whether to return the updated dataframe with the calculated values. Defaults to False.
    
    Returns:
        pd.DataFrame or list: The updated dataframe with the calculated values or a list of dataframes containing the calculated values
    """
    # Define rolling window size and minimum valid days based on period
    period_mapping = {
        '1M': {'window_size': 21, 'min_valid_days': 15},
        '3M': {'window_size': 63, 'min_valid_days': 50},
        '6M': {'window_size': 126, 'min_valid_days': 100},
        '12M': {'window_size': 252, 'min_valid_days': 200},
        '24M': {'window_size': 504, 'min_valid_days': 450}
    }
    
    if period not in period_mapping:
        raise ValueError(f"Invalid period. Please choose from {list(period_mapping.keys())}")
    
    window_size = period_mapping[period]['window_size']
    min_valid_days = period_mapping[period]['min_valid_days']


    print("Calculating beta_sw \n")
    
    print("Calculating beta_{t-1} \n")
    beta_tm1 = cal_beta(data.shift(-1), date, id, ret, mkt, period, dataframe=True) # 전체인데?
    print("-----------------------------------")
    print("Calculating beta_t \n")
    beta_t = cal_beta(data, date, id, ret, mkt, period, dataframe=True)
    print("-----------------------------------")
    print("Calculating beta_{t+1} \n")
    beta_tp1 = cal_beta(data.shift(1), date, id, ret, mkt, period, dataframe=True)
    
    rho_model = AutoReg(data[mkt], lags=1).fit()
    rho = rho_model.params[1]
    
    results_list = []

    for idx in range(len(beta_t)):
        # Calculate beta_sw
        beta_sum = beta_tm1[idx]['beta'] + beta_t[idx]['beta'] + beta_tp1[idx]['beta']
        beta_sw = beta_sum / (1 + 2 * rho)
        
        # Calculate standard error for beta_sw using the correct formula
        beta_se_tm1 = beta_tm1[idx]['beta_se']  # assuming beta_se is the standard error from the previous beta calculation
        beta_se_t = beta_t[idx]['beta_se']
        beta_se_tp1 = beta_tp1[idx]['beta_se']
        
        # Assuming the covariance between beta_{-1} and beta_{+1} is zero for simplicity
        beta_se_sw = np.sqrt(beta_se_t**2 + 0.25 * beta_se_tm1**2 + 0.25 * beta_se_tp1**2) / (1 + 2 * rho)
        beta_sw_t = beta_sw / beta_se_sw
        
        # Calculate alpha using beta_sw
        firm_len = len(beta_t[idx])
        if firm_len < min_valid_days:
            print(f"Skipping {f_id} due to insufficient data (size: {firm_len})")
            continue  # If the data is less than the minimum requirement, skip it.

        # When data length is less than window_size, adjust window_size to data length
        actual_window_size = min(firm_len, window_size)
        
        
        X_sw = sm.add_constant(data[data['permno'] == beta_t[idx].index]['mkt'])
        y_sw = data[data['permno'] == beta_t[idx].index]['ret']
        
        model_sw = RollingOLS(y_sw, X_sw, actual_window_size, min_nobs=min_valid_days)
        results_sw = model_sw.fit()
        
        alpha_sw = results_sw.params['const']
        alpha_sw_t = results_sw.tvalues['const']

        # Create a dataframe for the results
        sw_result = pd.DataFrame({
            date: beta_t[idx][date],
            'beta_sw': beta_sw,
            'beta_sw_t': beta_sw_t,
            'alpha_sw': alpha_sw,
            'alpha_sw_t': alpha_sw_t
        })

        results_list.append(sw_result)
    
    if dataframe:
        if results_list:
            results_df = pd.concat(results_list)
            data.update(results_df)
        return data
    
    return results_list

# %%
len(result)
# Out:
# 9377

# %%
result[0]
# Out:
#           beta    beta_t     alpha   alpha_t
# 5182       NaN       NaN       NaN       NaN
# 5183       NaN       NaN       NaN       NaN
# 5184       NaN       NaN       NaN       NaN
# 5185       NaN       NaN       NaN       NaN
# 5186       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...
# 6951  0.186605  4.924172  0.000451  0.784065
# 6952  0.186586  4.924340  0.000455  0.791009
# 6953  0.182207  4.782522  0.000504  0.870444
# 6954  0.182884  4.803584  0.000520  0.897247
# 6955  0.182595  4.795283  0.000540  0.931369
#
# [1763 rows x 4 columns]

# %%
def cal_beta_sw(data, date, id, ret, mkt, period, dataframe=False):
    """
    Calculate Scholes and Williams adjusted beta, its t-value, and corresponding alpha with its t-value.
    
    Parameters:
    data (pd.DataFrame): The dataset containing the required columns.
    date (str): The date column in the dataset.
    id (str): The column representing the unique identifier for each asset (e.g., stock ID).
    ret (str): The column representing the asset's returns.
    mkt (str): The column representing the market's returns.
    period (str): The rolling window period. Choose from '1M', '3M', '6M', '12M', '24M'.
    dataframe (bool): Whether to return the updated dataframe with the calculated values. Defaults to False.
    
    Returns:
        pd.DataFrame or list: The updated dataframe with the calculated values or a list of dataframes containing the calculated values
    """
    
    print("Calculating beta_sw \n")
    
    print("Calculating beta_{t-1} \n")
    beta_tm1 = cal_beta(data.shift(-1), date, id, ret, mkt, period, dataframe=False)
    print("-----------------------------------")
    print("Calculating beta_t \n")
    beta_t = cal_beta(data, date, id, ret, mkt, period, dataframe=False)
    print("-----------------------------------")
    print("Calculating beta_{t+1} \n")
    beta_tp1 = cal_beta(data.shift(1), date, id, ret, mkt, period, dataframe=False)
    
    rho_model = AutoReg(data[mkt], lags=1).fit()
    rho = rho_model.params[1]
    
    results_list = []

    for idx in range(len(beta_t)):
        beta_sum = beta_tm1[idx]['beta'] + beta_t[idx]['beta'] + beta_tp1[idx]['beta']
        beta_sw = beta_sum / (1 + 2 * rho)
        
        # Calculate standard error for beta_sw
        se_beta_tm1 = beta_tm1[idx]['beta_t'] / beta_tm1[idx]['beta']
        se_beta_t = beta_t[idx]['beta_t'] / beta_t[idx]['beta']
        se_beta_tp1 = beta_tp1[idx]['beta_t'] / beta_tp1[idx]['beta']
        
        se_beta_sw = np.sqrt(se_beta_tm1**2 + se_beta_t**2 + se_beta_tp1**2) / (1 + 2 * rho)
        beta_sw_t = beta_sw / se_beta_sw
        #
        # Calculate alpha using beta_sw
        X_sw = sm.add_constant(data[data['permno'] == beta_t[idx].index]['mkt'])
        y_sw = data[data['permno'] == beta_t[idx].index]['ret']
        
        model_sw = sm.OLS(y_sw, X_sw)
        results_sw = model_sw.fit()
        
        alpha_sw = results_sw.params['const']
        alpha_sw_t = results_sw.tvalues['const']

        # Create a dataframe for the results
        sw_result = pd.DataFrame({
            date: beta_t[idx][date],
            'beta_sw': beta_sw,
            'beta_sw_t': beta_sw_t,
            'alpha_sw': alpha_sw,
            'alpha_sw_t': alpha_sw_t
        })

        results_list.append(sw_result)
    
    if dataframe:
        if results_list:
            results_df = pd.concat(results_list)
            data.update(results_df)
        return data
    
    return results_list

# %%
sw_beta = cal_beta_sw(test_data, 'date', 'permno', 'ret', 'mktrf', '12M', True)
# Out:
# Calculating beta_sw
#
# Calculating beta_{t-1}
#
# Skipping 10012.0 due to insufficient data (size: 147)
# Skipping 10089.0 due to insufficient data (size: 39)
# Skipping 10108.0 due to insufficient data (size: 154)
# Skipping 10453.0 due to insufficient data (size: 166)
# Skipping 10691.0 due to insufficient data (size: 82)
# Skipping 10906.0 due to insufficient data (size: 40)
# Skipping 10935.0 due to insufficient data (size: 165)
# Skipping 11216.0 due to insufficient data (size: 168)
# Skipping 11262.0 due to insufficient data (size: 79)
# Skipping 11358.0 due to insufficient data (size: 167)
# Skipping 11371.0 due to insufficient data (size: 19)
# Skipping 11393.0 due to insufficient data (size: 168)
# Skipping 11473.0 due to insufficient data (size: 121)
# Skipping 11483.0 due to insufficient data (size: 73)
# Skipping 11485.0 due to insufficient data (size: 61)
# Skipping 11643.0 due to insufficient data (size: 54)
# Skipping 11646.0 due to insufficient data (size: 39)
# Skipping 11794.0 due to insufficient data (size: 133)
# Skipping 11803.0 due to insufficient data (size: 118)
# Skipping 11851.0 due to insufficient data (size: 90)
# Skipping 11901.0 due to insufficient data (size: 31)
# Skipping 12107.0 due to insufficient data (size: 180)
# Skipping 12174.0 due to insufficient data (size: 47)
# Skipping 12177.0 due to insufficient data (size: 117)
# Skipping 12265.0 due to insufficient data (size: 102)
# Skipping 12311.0 due to insufficient data (size: 137)
# Skipping 12346.0 due to insufficient data (size: 36)
# Skipping 12396.0 due to insufficient data (size: 197)
# Skipping 12485.0 due to insufficient data (size: 51)
# Skipping 12544.0 due to insufficient data (size: 27)
# Skipping 12591.0 due to insufficient data (size: 191)
# Skipping 12593.0 due to insufficient data (size: 192)
# Skipping 12594.0 due to insufficient data (size: 196)
# Skipping 12595.0 due to insufficient data (size: 196)
# Skipping 12596.0 due to insufficient data (size: 196)
# Skipping 12600.0 due to insufficient data (size: 191)
# Skipping 12601.0 due to insufficient data (size: 191)
# Skipping 12602.0 due to insufficient data (size: 191)
# Skipping 12603.0 due to insufficient data (size: 191)
# Skipping 12604.0 due to insufficient data (size: 191)
# Skipping 12605.0 due to insufficient data (size: 191)
# Skipping 12606.0 due to insufficient data (size: 191)
# Skipping 12607.0 due to insufficient data (size: 191)
# Skipping 12608.0 due to insufficient data (size: 191)
# Skipping 12609.0 due to insufficient data (size: 191)
# Skipping 12610.0 due to insufficient data (size: 191)
# Skipping 12611.0 due to insufficient data (size: 191)
# Skipping 12612.0 due to insufficient data (size: 191)
# Skipping 12613.0 due to insufficient data (size: 191)
# Skipping 12614.0 due to insufficient data (size: 191)
# Skipping 12615.0 due to insufficient data (size: 196)
# Skipping 12623.0 due to insufficient data (size: 190)
# Skipping 12624.0 due to insufficient data (size: 197)
# Skipping 12625.0 due to insufficient data (size: 190)
# Skipping 12627.0 due to insufficient data (size: 161)
# Skipping 12628.0 due to insufficient data (size: 190)
# Skipping 12632.0 due to insufficient data (size: 192)
# Skipping 12633.0 due to insufficient data (size: 197)
# Skipping 12636.0 due to insufficient data (size: 191)
# Skipping 12640.0 due to insufficient data (size: 194)
# Skipping 12641.0 due to insufficient data (size: 177)
# Skipping 12644.0 due to insufficient data (size: 184)
# Skipping 12645.0 due to insufficient data (size: 179)
# Skipping 12646.0 due to insufficient data (size: 177)
# Skipping 12647.0 due to insufficient data (size: 177)
# Skipping 12648.0 due to insufficient data (size: 177)
# Skipping 12649.0 due to insufficient data (size: 177)
# Skipping 12651.0 due to insufficient data (size: 177)
# Skipping 12652.0 due to insufficient data (size: 177)
# Skipping 12653.0 due to insufficient data (size: 177)
# Skipping 12654.0 due to insufficient data (size: 177)
# Skipping 12655.0 due to insufficient data (size: 177)
# Skipping 12656.0 due to insufficient data (size: 176)
# Skipping 12657.0 due to insufficient data (size: 176)
# Skipping 12658.0 due to insufficient data (size: 176)
# Skipping 12659.0 due to insufficient data (size: 176)
# Skipping 12660.0 due to insufficient data (size: 189)
# Skipping 12661.0 due to insufficient data (size: 181)
# Skipping 12662.0 due to insufficient data (size: 172)
# Skipping 12663.0 due to insufficient data (size: 172)
# Skipping 12664.0 due to insufficient data (size: 187)
# Skipping 12665.0 due to insufficient data (size: 180)
# Skipping 12666.0 due to insufficient data (size: 173)
# Skipping 12667.0 due to insufficient data (size: 184)
# Skipping 12668.0 due to insufficient data (size: 189)
# Skipping 12671.0 due to insufficient data (size: 187)
# Skipping 12672.0 due to insufficient data (size: 187)
# Skipping 12673.0 due to insufficient data (size: 180)
# Skipping 12674.0 due to insufficient data (size: 180)
# Skipping 12675.0 due to insufficient data (size: 185)
# Skipping 12676.0 due to insufficient data (size: 180)
# Skipping 12679.0 due to insufficient data (size: 185)
# Skipping 12680.0 due to insufficient data (size: 179)
# Skipping 12681.0 due to insufficient data (size: 179)
# Skipping 12682.0 due to insufficient data (size: 180)
# Skipping 12683.0 due to insufficient data (size: 176)
# Skipping 12684.0 due to insufficient data (size: 180)
# Skipping 12687.0 due to insufficient data (size: 180)
# Skipping 12688.0 due to insufficient data (size: 171)
# Skipping 12689.0 due to insufficient data (size: 184)
# Skipping 12690.0 due to insufficient data (size: 171)
# Skipping 12691.0 due to insufficient data (size: 175)
# Skipping 12692.0 due to insufficient data (size: 176)
# Skipping 12693.0 due to insufficient data (size: 184)
# Skipping 12695.0 due to insufficient data (size: 176)
# Skipping 12696.0 due to insufficient data (size: 180)
# Skipping 12697.0 due to insufficient data (size: 178)
# Skipping 12698.0 due to insufficient data (size: 188)
# Skipping 12699.0 due to insufficient data (size: 175)
# Skipping 12700.0 due to insufficient data (size: 180)
# Skipping 12718.0 due to insufficient data (size: 189)
# Skipping 12719.0 due to insufficient data (size: 152)
# Skipping 12720.0 due to insufficient data (size: 161)
# Skipping 12725.0 due to insufficient data (size: 152)
# Skipping 12726.0 due to insufficient data (size: 152)
# Skipping 12727.0 due to insufficient data (size: 152)
# Skipping 12728.0 due to insufficient data (size: 152)
# Skipping 12729.0 due to insufficient data (size: 161)
# Skipping 12732.0 due to insufficient data (size: 151)
# Skipping 12733.0 due to insufficient data (size: 166)
# Skipping 12734.0 due to insufficient data (size: 156)
# Skipping 12735.0 due to insufficient data (size: 168)
# Skipping 12736.0 due to insufficient data (size: 167)
# Skipping 12737.0 due to insufficient data (size: 153)
# Skipping 12738.0 due to insufficient data (size: 166)
# Skipping 12739.0 due to insufficient data (size: 155)
# Skipping 12740.0 due to insufficient data (size: 155)
# Skipping 12741.0 due to insufficient data (size: 151)
# Skipping 12742.0 due to insufficient data (size: 156)
# Skipping 12743.0 due to insufficient data (size: 151)
# Skipping 12744.0 due to insufficient data (size: 161)
# Skipping 12745.0 due to insufficient data (size: 161)
# Skipping 12746.0 due to insufficient data (size: 166)
# Skipping 12747.0 due to insufficient data (size: 155)
# Skipping 12748.0 due to insufficient data (size: 151)
# Skipping 12751.0 due to insufficient data (size: 161)
# Skipping 12752.0 due to insufficient data (size: 151)
# Skipping 12753.0 due to insufficient data (size: 166)
# Skipping 12754.0 due to insufficient data (size: 166)
# Skipping 12755.0 due to insufficient data (size: 154)
# Skipping 12756.0 due to insufficient data (size: 162)
# Skipping 12759.0 due to insufficient data (size: 167)
# Skipping 12760.0 due to insufficient data (size: 164)
# Skipping 12761.0 due to insufficient data (size: 150)
# Skipping 12762.0 due to insufficient data (size: 150)
# Skipping 12763.0 due to insufficient data (size: 150)
# Skipping 12764.0 due to insufficient data (size: 150)
# Skipping 12767.0 due to insufficient data (size: 150)
# Skipping 12768.0 due to insufficient data (size: 150)
# Skipping 12769.0 due to insufficient data (size: 150)
# Skipping 12770.0 due to insufficient data (size: 150)
# Skipping 12771.0 due to insufficient data (size: 150)
# Skipping 12772.0 due to insufficient data (size: 149)
# Skipping 12775.0 due to insufficient data (size: 156)
# Skipping 12776.0 due to insufficient data (size: 156)
# Skipping 12777.0 due to insufficient data (size: 156)
# Skipping 12778.0 due to insufficient data (size: 156)
# Skipping 12779.0 due to insufficient data (size: 156)
# Skipping 12780.0 due to insufficient data (size: 156)
# Skipping 12782.0 due to insufficient data (size: 151)
# Skipping 12783.0 due to insufficient data (size: 166)
# Skipping 12784.0 due to insufficient data (size: 159)
# Skipping 12785.0 due to insufficient data (size: 169)
# Skipping 12786.0 due to insufficient data (size: 166)
# Skipping 12787.0 due to insufficient data (size: 151)
# Skipping 12788.0 due to insufficient data (size: 162)
# Skipping 12789.0 due to insufficient data (size: 156)
# Skipping 12791.0 due to insufficient data (size: 162)
# Skipping 12792.0 due to insufficient data (size: 122)
# Skipping 12793.0 due to insufficient data (size: 162)
# Skipping 12794.0 due to insufficient data (size: 152)
# Skipping 12795.0 due to insufficient data (size: 167)
# Skipping 12796.0 due to insufficient data (size: 151)
# Skipping 12797.0 due to insufficient data (size: 150)
# Skipping 12798.0 due to insufficient data (size: 167)
# Skipping 12799.0 due to insufficient data (size: 153)
# Skipping 12826.0 due to insufficient data (size: 163)
# Skipping 12827.0 due to insufficient data (size: 152)
# Skipping 12828.0 due to insufficient data (size: 127)
# Skipping 12831.0 due to insufficient data (size: 132)
# Skipping 12832.0 due to insufficient data (size: 134)
# Skipping 12833.0 due to insufficient data (size: 134)
# Skipping 12834.0 due to insufficient data (size: 134)
# Skipping 12835.0 due to insufficient data (size: 136)
# Skipping 12836.0 due to insufficient data (size: 143)
# Skipping 12839.0 due to insufficient data (size: 141)
# Skipping 12840.0 due to insufficient data (size: 141)
# Skipping 12841.0 due to insufficient data (size: 142)
# Skipping 12842.0 due to insufficient data (size: 142)
# Skipping 12843.0 due to insufficient data (size: 142)
# Skipping 12844.0 due to insufficient data (size: 142)
# Skipping 12847.0 due to insufficient data (size: 142)
# Skipping 12848.0 due to insufficient data (size: 138)
# Skipping 12849.0 due to insufficient data (size: 138)
# Skipping 12850.0 due to insufficient data (size: 138)
# Skipping 12851.0 due to insufficient data (size: 138)
# Skipping 12852.0 due to insufficient data (size: 138)
# Skipping 12855.0 due to insufficient data (size: 132)
# Skipping 12856.0 due to insufficient data (size: 132)
# Skipping 12857.0 due to insufficient data (size: 132)
# Skipping 12858.0 due to insufficient data (size: 132)
# Skipping 12859.0 due to insufficient data (size: 132)
# Skipping 12860.0 due to insufficient data (size: 132)
# Skipping 12863.0 due to insufficient data (size: 132)
# Skipping 12864.0 due to insufficient data (size: 132)
# Skipping 12865.0 due to insufficient data (size: 142)
# Skipping 12866.0 due to insufficient data (size: 147)
# Skipping 12867.0 due to insufficient data (size: 142)
# Skipping 12868.0 due to insufficient data (size: 139)
# Skipping 12869.0 due to insufficient data (size: 143)
# Skipping 12870.0 due to insufficient data (size: 136)
# Skipping 12871.0 due to insufficient data (size: 138)
# Skipping 12872.0 due to insufficient data (size: 126)
# Skipping 12873.0 due to insufficient data (size: 138)
# Skipping 12874.0 due to insufficient data (size: 136)
# Skipping 12875.0 due to insufficient data (size: 137)
# Skipping 12876.0 due to insufficient data (size: 137)
# Skipping 12877.0 due to insufficient data (size: 132)
# Skipping 12878.0 due to insufficient data (size: 142)
# Skipping 12879.0 due to insufficient data (size: 133)
# Skipping 12880.0 due to insufficient data (size: 126)
# Skipping 12881.0 due to insufficient data (size: 130)
# Skipping 12882.0 due to insufficient data (size: 128)
# Skipping 12883.0 due to insufficient data (size: 127)
# Skipping 12884.0 due to insufficient data (size: 127)
# Skipping 12885.0 due to insufficient data (size: 134)
# Skipping 12886.0 due to insufficient data (size: 147)
# Skipping 12887.0 due to insufficient data (size: 131)
# Skipping 12890.0 due to insufficient data (size: 138)
# Skipping 12891.0 due to insufficient data (size: 148)
# Skipping 12892.0 due to insufficient data (size: 109)
# Skipping 12893.0 due to insufficient data (size: 112)
# Skipping 12894.0 due to insufficient data (size: 107)
# Skipping 12895.0 due to insufficient data (size: 109)
# Skipping 12898.0 due to insufficient data (size: 119)
# Skipping 12899.0 due to insufficient data (size: 119)
# Skipping 12900.0 due to insufficient data (size: 118)
# Skipping 12901.0 due to insufficient data (size: 119)
# Skipping 12902.0 due to insufficient data (size: 118)
# Skipping 12903.0 due to insufficient data (size: 114)
# Skipping 12904.0 due to insufficient data (size: 118)
# Skipping 12905.0 due to insufficient data (size: 113)
# Skipping 12906.0 due to insufficient data (size: 109)
# Skipping 12907.0 due to insufficient data (size: 108)
# Skipping 12908.0 due to insufficient data (size: 108)
# Skipping 12911.0 due to insufficient data (size: 118)
# Skipping 12912.0 due to insufficient data (size: 111)
# Skipping 12913.0 due to insufficient data (size: 108)
# Skipping 12914.0 due to insufficient data (size: 109)
# Skipping 12915.0 due to insufficient data (size: 112)
# Skipping 12916.0 due to insufficient data (size: 124)
# Skipping 12919.0 due to insufficient data (size: 108)
# Skipping 12920.0 due to insufficient data (size: 122)
# Skipping 12921.0 due to insufficient data (size: 123)
# Skipping 12922.0 due to insufficient data (size: 114)
# Skipping 12923.0 due to insufficient data (size: 124)
# Skipping 12924.0 due to insufficient data (size: 109)
# Skipping 12927.0 due to insufficient data (size: 114)
# Skipping 12946.0 due to insufficient data (size: 87)
# Skipping 12947.0 due to insufficient data (size: 103)
# Skipping 12948.0 due to insufficient data (size: 99)
# Skipping 12949.0 due to insufficient data (size: 93)
# Skipping 12950.0 due to insufficient data (size: 93)
# Skipping 12951.0 due to insufficient data (size: 93)
# Skipping 12952.0 due to insufficient data (size: 106)
# Skipping 12953.0 due to insufficient data (size: 94)
# Skipping 12954.0 due to insufficient data (size: 96)
# Skipping 12955.0 due to insufficient data (size: 103)
# Skipping 12956.0 due to insufficient data (size: 103)
# Skipping 12957.0 due to insufficient data (size: 98)
# Skipping 12959.0 due to insufficient data (size: 104)
# Skipping 12960.0 due to insufficient data (size: 98)
# Skipping 12961.0 due to insufficient data (size: 91)
# Skipping 12962.0 due to insufficient data (size: 77)
# Skipping 12963.0 due to insufficient data (size: 95)
# Skipping 12964.0 due to insufficient data (size: 104)
# Skipping 12965.0 due to insufficient data (size: 103)
# Skipping 12966.0 due to insufficient data (size: 86)
# Skipping 12967.0 due to insufficient data (size: 93)
# Skipping 12970.0 due to insufficient data (size: 94)
# Skipping 12971.0 due to insufficient data (size: 97)
# Skipping 12972.0 due to insufficient data (size: 100)
# Skipping 12973.0 due to insufficient data (size: 69)
# Skipping 12974.0 due to insufficient data (size: 65)
# Skipping 12975.0 due to insufficient data (size: 69)
# Skipping 12978.0 due to insufficient data (size: 69)
# Skipping 12979.0 due to insufficient data (size: 69)
# Skipping 12980.0 due to insufficient data (size: 69)
# Skipping 12981.0 due to insufficient data (size: 61)
# Skipping 12982.0 due to insufficient data (size: 71)
# Skipping 12983.0 due to insufficient data (size: 80)
# Skipping 12986.0 due to insufficient data (size: 76)
# Skipping 12987.0 due to insufficient data (size: 76)
# Skipping 12988.0 due to insufficient data (size: 80)
# Skipping 12989.0 due to insufficient data (size: 80)
# Skipping 12990.0 due to insufficient data (size: 80)
# Skipping 12991.0 due to insufficient data (size: 76)
# Skipping 12994.0 due to insufficient data (size: 79)
# Skipping 12995.0 due to insufficient data (size: 68)
# Skipping 12996.0 due to insufficient data (size: 74)
# Skipping 12997.0 due to insufficient data (size: 64)
# Skipping 12998.0 due to insufficient data (size: 64)
# Skipping 12999.0 due to insufficient data (size: 64)
# Skipping 13000.0 due to insufficient data (size: 72)
# Skipping 13001.0 due to insufficient data (size: 72)
# Skipping 13002.0 due to insufficient data (size: 72)
# Skipping 13003.0 due to insufficient data (size: 80)
# Skipping 13006.0 due to insufficient data (size: 74)
# Skipping 13007.0 due to insufficient data (size: 79)
# Skipping 13008.0 due to insufficient data (size: 67)
# Skipping 13009.0 due to insufficient data (size: 67)
# Skipping 13010.0 due to insufficient data (size: 44)
# Skipping 13011.0 due to insufficient data (size: 44)
# Skipping 13013.0 due to insufficient data (size: 59)
# Skipping 13014.0 due to insufficient data (size: 76)
# Skipping 13015.0 due to insufficient data (size: 81)
# Skipping 13016.0 due to insufficient data (size: 60)
# Skipping 13017.0 due to insufficient data (size: 61)
# Skipping 13018.0 due to insufficient data (size: 41)
# Skipping 13019.0 due to insufficient data (size: 42)
# Skipping 13022.0 due to insufficient data (size: 44)
# Skipping 13023.0 due to insufficient data (size: 49)
# Skipping 13024.0 due to insufficient data (size: 49)
# Skipping 13025.0 due to insufficient data (size: 49)
# Skipping 13026.0 due to insufficient data (size: 49)
# Skipping 13027.0 due to insufficient data (size: 49)
# Skipping 13028.0 due to insufficient data (size: 55)
# Skipping 13029.0 due to insufficient data (size: 61)
# Skipping 13030.0 due to insufficient data (size: 61)
# Skipping 13031.0 due to insufficient data (size: 59)
# Skipping 13032.0 due to insufficient data (size: 59)
# Skipping 13033.0 due to insufficient data (size: 49)
# Skipping 13034.0 due to insufficient data (size: 44)
# Skipping 13035.0 due to insufficient data (size: 41)
# Skipping 13036.0 due to insufficient data (size: 55)
# Skipping 13037.0 due to insufficient data (size: 60)
# Skipping 13038.0 due to insufficient data (size: 44)
# Skipping 13041.0 due to insufficient data (size: 41)
# Skipping 13042.0 due to insufficient data (size: 60)
# Skipping 13043.0 due to insufficient data (size: 60)
# Skipping 13044.0 due to insufficient data (size: 60)
# Skipping 13045.0 due to insufficient data (size: 60)
# Skipping 13046.0 due to insufficient data (size: 53)
# Skipping 13049.0 due to insufficient data (size: 50)
# Skipping 13076.0 due to insufficient data (size: 25)
# Skipping 13077.0 due to insufficient data (size: 33)
# Skipping 13078.0 due to insufficient data (size: 28)
# Skipping 13079.0 due to insufficient data (size: 39)
# Skipping 13080.0 due to insufficient data (size: 35)
# Skipping 13081.0 due to insufficient data (size: 30)
# Skipping 13082.0 due to insufficient data (size: 29)
# Skipping 13083.0 due to insufficient data (size: 33)
# Skipping 13084.0 due to insufficient data (size: 28)
# Skipping 13085.0 due to insufficient data (size: 26)
# Skipping 13086.0 due to insufficient data (size: 41)
# Skipping 13087.0 due to insufficient data (size: 34)
# Skipping 13088.0 due to insufficient data (size: 34)
# Skipping 13089.0 due to insufficient data (size: 41)
# Skipping 13090.0 due to insufficient data (size: 41)
# Skipping 13091.0 due to insufficient data (size: 41)
# Skipping 13092.0 due to insufficient data (size: 41)
# Skipping 13093.0 due to insufficient data (size: 38)
# Skipping 13094.0 due to insufficient data (size: 39)
# Skipping 13095.0 due to insufficient data (size: 39)
# Skipping 13096.0 due to insufficient data (size: 39)
# Skipping 13097.0 due to insufficient data (size: 38)
# Skipping 13100.0 due to insufficient data (size: 166)
# Skipping 13102.0 due to insufficient data (size: 31)
# Skipping 13103.0 due to insufficient data (size: 29)
# Skipping 13104.0 due to insufficient data (size: 33)
# Skipping 13105.0 due to insufficient data (size: 41)
# Skipping 13106.0 due to insufficient data (size: 29)
# Skipping 13107.0 due to insufficient data (size: 30)
# Skipping 13108.0 due to insufficient data (size: 38)
# Skipping 13109.0 due to insufficient data (size: 28)
# Skipping 13110.0 due to insufficient data (size: 28)
# Skipping 13111.0 due to insufficient data (size: 33)
# Skipping 13112.0 due to insufficient data (size: 31)
# Skipping 13113.0 due to insufficient data (size: 40)
# Skipping 13114.0 due to insufficient data (size: 31)
# Skipping 13116.0 due to insufficient data (size: 10)
# Skipping 13117.0 due to insufficient data (size: 15)
# Skipping 13118.0 due to insufficient data (size: 15)
# Skipping 13121.0 due to insufficient data (size: 18)
# Skipping 13122.0 due to insufficient data (size: 15)
# Skipping 13123.0 due to insufficient data (size: 9)
# Skipping 13124.0 due to insufficient data (size: 10)
# Skipping 13125.0 due to insufficient data (size: 6)
# Skipping 13126.0 due to insufficient data (size: 6)
# Skipping 13129.0 due to insufficient data (size: 6)
# Skipping 13130.0 due to insufficient data (size: 6)
# Skipping 13131.0 due to insufficient data (size: 6)
# Skipping 13132.0 due to insufficient data (size: 6)
# Skipping 13133.0 due to insufficient data (size: 14)
# Skipping 13137.0 due to insufficient data (size: 20)
# Skipping 13138.0 due to insufficient data (size: 20)
# Skipping 13139.0 due to insufficient data (size: 11)
# Skipping 13140.0 due to insufficient data (size: 19)
# Skipping 13142.0 due to insufficient data (size: 10)
# Skipping 13145.0 due to insufficient data (size: 11)
# Skipping 13159.0 due to insufficient data (size: 8)
# Skipping 13160.0 due to insufficient data (size: 12)
# Skipping 13161.0 due to insufficient data (size: 13)
# Skipping 13162.0 due to insufficient data (size: 10)
# Skipping 13163.0 due to insufficient data (size: 14)
# Skipping 13165.0 due to insufficient data (size: 17)
# Skipping 13166.0 due to insufficient data (size: 17)
# Skipping 13167.0 due to insufficient data (size: 20)
# Skipping 13168.0 due to insufficient data (size: 6)
# Skipping 13169.0 due to insufficient data (size: 9)
# Skipping 14059.0 due to insufficient data (size: 174)
# Skipping 14322.0 due to insufficient data (size: 57)
# Skipping 14891.0 due to insufficient data (size: 153)
# Skipping 16424.0 due to insufficient data (size: 189)
# Skipping 16715.0 due to insufficient data (size: 92)
# Skipping 17337.0 due to insufficient data (size: 44)
# Skipping 17559.0 due to insufficient data (size: 144)
# Skipping 22569.0 due to insufficient data (size: 26)
# Skipping 24572.0 due to insufficient data (size: 92)
# Skipping 24803.0 due to insufficient data (size: 34)
# Skipping 25786.0 due to insufficient data (size: 140)
# Skipping 26060.0 due to insufficient data (size: 189)
# Skipping 26083.0 due to insufficient data (size: 137)
# Skipping 26112.0 due to insufficient data (size: 197)
# Skipping 30307.0 due to insufficient data (size: 25)
# Skipping 32379.0 due to insufficient data (size: 126)
# Skipping 34287.0 due to insufficient data (size: 125)
# Skipping 34463.0 due to insufficient data (size: 41)
# Skipping 36709.0 due to insufficient data (size: 94)
# Skipping 38333.0 due to insufficient data (size: 157)
# Skipping 39773.0 due to insufficient data (size: 65)
# Skipping 40097.0 due to insufficient data (size: 44)
# Skipping 43028.0 due to insufficient data (size: 179)
# Skipping 43692.0 due to insufficient data (size: 4)
# Skipping 43705.0 due to insufficient data (size: 4)
# Skipping 44353.0 due to insufficient data (size: 100)
# Skipping 45110.0 due to insufficient data (size: 18)
# Skipping 45129.0 due to insufficient data (size: 126)
# Skipping 45348.0 due to insufficient data (size: 190)
# Skipping 45744.0 due to insufficient data (size: 81)
# Skipping 46843.0 due to insufficient data (size: 163)
# Skipping 48143.0 due to insufficient data (size: 60)
# Skipping 48696.0 due to insufficient data (size: 145)
# Skipping 53946.0 due to insufficient data (size: 176)
# Skipping 54843.0 due to insufficient data (size: 152)
# Skipping 56354.0 due to insufficient data (size: 183)
# Skipping 56813.0 due to insufficient data (size: 72)
# Skipping 56987.0 due to insufficient data (size: 94)
# Skipping 57066.0 due to insufficient data (size: 35)
# Skipping 57584.0 due to insufficient data (size: 34)
# Skipping 57780.0 due to insufficient data (size: 96)
# Skipping 57884.0 due to insufficient data (size: 17)
# Skipping 58464.0 due to insufficient data (size: 168)
# Skipping 61065.0 due to insufficient data (size: 139)
# Skipping 64004.0 due to insufficient data (size: 177)
# Skipping 65533.0 due to insufficient data (size: 78)
# Skipping 65702.0 due to insufficient data (size: 168)
# Skipping 66369.0 due to insufficient data (size: 36)
# Skipping 66472.0 due to insufficient data (size: 20)
# Skipping 66967.0 due to insufficient data (size: 92)
# Skipping 68065.0 due to insufficient data (size: 51)
# Skipping 69518.0 due to insufficient data (size: 121)
# Skipping 69542.0 due to insufficient data (size: 182)
# Skipping 70156.0 due to insufficient data (size: 163)
# Skipping 70659.0 due to insufficient data (size: 93)
# Skipping 71598.0 due to insufficient data (size: 51)
# Skipping 74580.0 due to insufficient data (size: 192)
# Skipping 75243.0 due to insufficient data (size: 38)
# Skipping 75244.0 due to insufficient data (size: 86)
# Skipping 75264.0 due to insufficient data (size: 133)
# Skipping 75286.0 due to insufficient data (size: 49)
# Skipping 75350.0 due to insufficient data (size: 140)
# Skipping 75351.0 due to insufficient data (size: 186)
# Skipping 75365.0 due to insufficient data (size: 194)
# Skipping 75391.0 due to insufficient data (size: 37)
# Skipping 75393.0 due to insufficient data (size: 42)
# Skipping 75446.0 due to insufficient data (size: 145)
# Skipping 75581.0 due to insufficient data (size: 166)
# Skipping 75609.0 due to insufficient data (size: 139)
# Skipping 75826.0 due to insufficient data (size: 149)
# Skipping 75845.0 due to insufficient data (size: 165)
# Skipping 76101.0 due to insufficient data (size: 48)
# Skipping 76165.0 due to insufficient data (size: 183)
# Skipping 76259.0 due to insufficient data (size: 73)
# Skipping 76299.0 due to insufficient data (size: 77)
# Skipping 76302.0 due to insufficient data (size: 155)
# Skipping 76308.0 due to insufficient data (size: 25)
# Skipping 76443.0 due to insufficient data (size: 190)
# Skipping 76445.0 due to insufficient data (size: 125)
# Skipping 76448.0 due to insufficient data (size: 110)
# Skipping 76513.0 due to insufficient data (size: 177)
# Skipping 76830.0 due to insufficient data (size: 41)
# Skipping 76898.0 due to insufficient data (size: 165)
# Skipping 76937.0 due to insufficient data (size: 81)
# Skipping 77106.0 due to insufficient data (size: 100)
# Skipping 77133.0 due to insufficient data (size: 145)
# Skipping 77155.0 due to insufficient data (size: 88)
# Skipping 77217.0 due to insufficient data (size: 110)
# Skipping 77254.0 due to insufficient data (size: 151)
# Skipping 77284.0 due to insufficient data (size: 155)
# Skipping 77334.0 due to insufficient data (size: 15)
# Skipping 77339.0 due to insufficient data (size: 99)
# Skipping 77427.0 due to insufficient data (size: 48)
# Skipping 77489.0 due to insufficient data (size: 82)
# Skipping 77639.0 due to insufficient data (size: 145)
# Skipping 77839.0 due to insufficient data (size: 165)
# Skipping 77887.0 due to insufficient data (size: 167)
# Skipping 78083.0 due to insufficient data (size: 5)
# Skipping 78236.0 due to insufficient data (size: 105)
# Skipping 78560.0 due to insufficient data (size: 151)
# Skipping 78721.0 due to insufficient data (size: 189)
# Skipping 78752.0 due to insufficient data (size: 104)
# Skipping 78846.0 due to insufficient data (size: 146)
# Skipping 78856.0 due to insufficient data (size: 194)
# Skipping 78867.0 due to insufficient data (size: 190)
# Skipping 78871.0 due to insufficient data (size: 31)
# Skipping 78914.0 due to insufficient data (size: 62)
# Skipping 78956.0 due to insufficient data (size: 191)
# Skipping 79005.0 due to insufficient data (size: 198)
# Skipping 79029.0 due to insufficient data (size: 165)
# Skipping 79087.0 due to insufficient data (size: 53)
# Skipping 79146.0 due to insufficient data (size: 65)
# Skipping 79204.0 due to insufficient data (size: 179)
# Skipping 79339.0 due to insufficient data (size: 149)
# Skipping 79361.0 due to insufficient data (size: 194)
# Skipping 79392.0 due to insufficient data (size: 80)
# Skipping 79420.0 due to insufficient data (size: 42)
# Skipping 79428.0 due to insufficient data (size: 114)
# Skipping 79512.0 due to insufficient data (size: 34)
# Skipping 79591.0 due to insufficient data (size: 136)
# Skipping 79670.0 due to insufficient data (size: 123)
# Skipping 79726.0 due to insufficient data (size: 15)
# Skipping 79742.0 due to insufficient data (size: 39)
# Skipping 79801.0 due to insufficient data (size: 189)
# Skipping 79845.0 due to insufficient data (size: 192)
# Skipping 79910.0 due to insufficient data (size: 108)
# Skipping 79944.0 due to insufficient data (size: 152)
# Skipping 79950.0 due to insufficient data (size: 110)
# Skipping 79971.0 due to insufficient data (size: 186)
# Skipping 80055.0 due to insufficient data (size: 126)
# Skipping 80122.0 due to insufficient data (size: 95)
# Skipping 80173.0 due to insufficient data (size: 117)
# Skipping 80178.0 due to insufficient data (size: 189)
# Skipping 80212.0 due to insufficient data (size: 39)
# Skipping 80290.0 due to insufficient data (size: 4)
# Skipping 80345.0 due to insufficient data (size: 184)
# Skipping 80359.0 due to insufficient data (size: 70)
# Skipping 80629.0 due to insufficient data (size: 189)
# Skipping 80713.0 due to insufficient data (size: 90)
# Skipping 80730.0 due to insufficient data (size: 131)
# Skipping 80778.0 due to insufficient data (size: 185)
# Skipping 80852.0 due to insufficient data (size: 22)
# Skipping 80946.0 due to insufficient data (size: 97)
# Skipping 80958.0 due to insufficient data (size: 103)
# Skipping 81002.0 due to insufficient data (size: 121)
# Skipping 81020.0 due to insufficient data (size: 125)
# Skipping 81060.0 due to insufficient data (size: 179)
# Skipping 81098.0 due to insufficient data (size: 152)
# Skipping 81125.0 due to insufficient data (size: 145)
# Skipping 81185.0 due to insufficient data (size: 80)
# Skipping 81214.0 due to insufficient data (size: 4)
# Skipping 81233.0 due to insufficient data (size: 167)
# Skipping 81244.0 due to insufficient data (size: 183)
# Skipping 81290.0 due to insufficient data (size: 55)
# Skipping 81483.0 due to insufficient data (size: 128)
# Skipping 81510.0 due to insufficient data (size: 152)
# Skipping 81590.0 due to insufficient data (size: 35)
# Skipping 81601.0 due to insufficient data (size: 130)
# Skipping 81636.0 due to insufficient data (size: 189)
# Skipping 81672.0 due to insufficient data (size: 14)
# Skipping 81709.0 due to insufficient data (size: 19)
# Skipping 81710.0 due to insufficient data (size: 103)
# Skipping 81726.0 due to insufficient data (size: 115)
# Skipping 81865.0 due to insufficient data (size: 41)
# Skipping 81904.0 due to insufficient data (size: 24)
# Skipping 82236.0 due to insufficient data (size: 157)
# Skipping 82294.0 due to insufficient data (size: 14)
# Skipping 82478.0 due to insufficient data (size: 23)
# Skipping 82511.0 due to insufficient data (size: 187)
# Skipping 82549.0 due to insufficient data (size: 67)
# Skipping 82680.0 due to insufficient data (size: 97)
# Skipping 82681.0 due to insufficient data (size: 130)
# Skipping 82724.0 due to insufficient data (size: 61)
# Skipping 82767.0 due to insufficient data (size: 136)
# Skipping 82805.0 due to insufficient data (size: 129)
# Skipping 83163.0 due to insufficient data (size: 97)
# Skipping 83236.0 due to insufficient data (size: 5)
# Skipping 83295.0 due to insufficient data (size: 7)
# Skipping 83334.0 due to insufficient data (size: 25)
# Skipping 83404.0 due to insufficient data (size: 145)
# Skipping 83444.0 due to insufficient data (size: 61)
# Skipping 83455.0 due to insufficient data (size: 93)
# Skipping 83456.0 due to insufficient data (size: 100)
# Skipping 83478.0 due to insufficient data (size: 125)
# Skipping 83496.0 due to insufficient data (size: 134)
# Skipping 83581.0 due to insufficient data (size: 145)
# Skipping 83590.0 due to insufficient data (size: 96)
# Skipping 83650.0 due to insufficient data (size: 77)
# Skipping 83657.0 due to insufficient data (size: 121)
# Skipping 83764.0 due to insufficient data (size: 38)
# Skipping 83813.0 due to insufficient data (size: 90)
# Skipping 83918.0 due to insufficient data (size: 72)
# Skipping 83926.0 due to insufficient data (size: 147)
# Skipping 83967.0 due to insufficient data (size: 106)
# Skipping 84133.0 due to insufficient data (size: 18)
# Skipping 84136.0 due to insufficient data (size: 143)
# Skipping 84193.0 due to insufficient data (size: 147)
# Skipping 84211.0 due to insufficient data (size: 97)
# Skipping 84223.0 due to insufficient data (size: 159)
# Skipping 84229.0 due to insufficient data (size: 146)
# Skipping 84232.0 due to insufficient data (size: 183)
# Skipping 84240.0 due to insufficient data (size: 11)
# Skipping 84307.0 due to insufficient data (size: 158)
# Skipping 84369.0 due to insufficient data (size: 65)
# Skipping 84431.0 due to insufficient data (size: 67)
# Skipping 84508.0 due to insufficient data (size: 21)
# Skipping 84525.0 due to insufficient data (size: 105)
# Skipping 84536.0 due to insufficient data (size: 47)
# Skipping 84605.0 due to insufficient data (size: 9)
# Skipping 84629.0 due to insufficient data (size: 181)
# Skipping 84650.0 due to insufficient data (size: 170)
# Skipping 84659.0 due to insufficient data (size: 62)
# Skipping 84666.0 due to insufficient data (size: 173)
# Skipping 85005.0 due to insufficient data (size: 93)
# Skipping 85057.0 due to insufficient data (size: 80)
# Skipping 85073.0 due to insufficient data (size: 189)
# Skipping 85197.0 due to insufficient data (size: 38)
# Skipping 85202.0 due to insufficient data (size: 29)
# Skipping 85210.0 due to insufficient data (size: 3)
# Skipping 85267.0 due to insufficient data (size: 135)
# Skipping 85304.0 due to insufficient data (size: 4)
# Skipping 85358.0 due to insufficient data (size: 192)
# Skipping 85431.0 due to insufficient data (size: 23)
# Skipping 85458.0 due to insufficient data (size: 108)
# Skipping 85463.0 due to insufficient data (size: 132)
# Skipping 85495.0 due to insufficient data (size: 199)
# Skipping 85620.0 due to insufficient data (size: 67)
# Skipping 85624.0 due to insufficient data (size: 126)
# Skipping 85740.0 due to insufficient data (size: 5)
# Skipping 85816.0 due to insufficient data (size: 133)
# Skipping 85817.0 due to insufficient data (size: 43)
# Skipping 85874.0 due to insufficient data (size: 165)
# Skipping 85890.0 due to insufficient data (size: 184)
# Skipping 85933.0 due to insufficient data (size: 72)
# Skipping 85950.0 due to insufficient data (size: 96)
# Skipping 86037.0 due to insufficient data (size: 44)
# Skipping 86063.0 due to insufficient data (size: 69)
# Skipping 86156.0 due to insufficient data (size: 60)
# Skipping 86194.0 due to insufficient data (size: 186)
# Skipping 86215.0 due to insufficient data (size: 86)
# Skipping 86224.0 due to insufficient data (size: 98)
# Skipping 86248.0 due to insufficient data (size: 145)
# Skipping 86259.0 due to insufficient data (size: 194)
# Skipping 86268.0 due to insufficient data (size: 10)
# Skipping 86293.0 due to insufficient data (size: 125)
# Skipping 86401.0 due to insufficient data (size: 54)
# Skipping 86447.0 due to insufficient data (size: 112)
# Skipping 86579.0 due to insufficient data (size: 14)
# Skipping 86591.0 due to insufficient data (size: 195)
# Skipping 86748.0 due to insufficient data (size: 194)
# Skipping 86758.0 due to insufficient data (size: 106)
# Skipping 86761.0 due to insufficient data (size: 103)
# Skipping 86770.0 due to insufficient data (size: 25)
# Skipping 86813.0 due to insufficient data (size: 159)
# Skipping 86885.0 due to insufficient data (size: 104)
# Skipping 86913.0 due to insufficient data (size: 123)
# Skipping 86917.0 due to insufficient data (size: 103)
# Skipping 87030.0 due to insufficient data (size: 128)
# Skipping 87060.0 due to insufficient data (size: 114)
# Skipping 87079.0 due to insufficient data (size: 148)
# Skipping 87085.0 due to insufficient data (size: 169)
# Skipping 87087.0 due to insufficient data (size: 128)
# Skipping 87093.0 due to insufficient data (size: 178)
# Skipping 87095.0 due to insufficient data (size: 23)
# Skipping 87100.0 due to insufficient data (size: 137)
# Skipping 87147.0 due to insufficient data (size: 180)
# Skipping 87227.0 due to insufficient data (size: 55)
# Skipping 87228.0 due to insufficient data (size: 188)
# Skipping 87241.0 due to insufficient data (size: 199)
# Skipping 87248.0 due to insufficient data (size: 31)
# Skipping 87281.0 due to insufficient data (size: 193)
# Skipping 87283.0 due to insufficient data (size: 193)
# Skipping 87293.0 due to insufficient data (size: 94)
# Skipping 87385.0 due to insufficient data (size: 87)
# Skipping 87387.0 due to insufficient data (size: 38)
# Skipping 87401.0 due to insufficient data (size: 63)
# Skipping 87412.0 due to insufficient data (size: 68)
# Skipping 87425.0 due to insufficient data (size: 135)
# Skipping 87435.0 due to insufficient data (size: 111)
# Skipping 87465.0 due to insufficient data (size: 37)
# Skipping 87472.0 due to insufficient data (size: 185)
# Skipping 87621.0 due to insufficient data (size: 145)
# Skipping 87642.0 due to insufficient data (size: 155)
# Skipping 87795.0 due to insufficient data (size: 20)
# Skipping 87826.0 due to insufficient data (size: 137)
# Skipping 87828.0 due to insufficient data (size: 123)
# Skipping 87839.0 due to insufficient data (size: 83)
# Skipping 88156.0 due to insufficient data (size: 24)
# Skipping 88158.0 due to insufficient data (size: 189)
# Skipping 88180.0 due to insufficient data (size: 179)
# Skipping 88187.0 due to insufficient data (size: 108)
# Skipping 88198.0 due to insufficient data (size: 164)
# Skipping 88256.0 due to insufficient data (size: 125)
# Skipping 88270.0 due to insufficient data (size: 80)
# Skipping 88273.0 due to insufficient data (size: 170)
# Skipping 88275.0 due to insufficient data (size: 179)
# Skipping 88305.0 due to insufficient data (size: 73)
# Skipping 88393.0 due to insufficient data (size: 119)
# Skipping 88418.0 due to insufficient data (size: 129)
# Skipping 88425.0 due to insufficient data (size: 92)
# Skipping 88431.0 due to insufficient data (size: 50)
# Skipping 88441.0 due to insufficient data (size: 76)
# Skipping 88460.0 due to insufficient data (size: 125)
# Skipping 88500.0 due to insufficient data (size: 95)
# Skipping 88527.0 due to insufficient data (size: 193)
# Skipping 88578.0 due to insufficient data (size: 176)
# Skipping 88585.0 due to insufficient data (size: 118)
# Skipping 88622.0 due to insufficient data (size: 114)
# Skipping 88625.0 due to insufficient data (size: 168)
# Skipping 88631.0 due to insufficient data (size: 2)
# Skipping 88651.0 due to insufficient data (size: 62)
# Skipping 88737.0 due to insufficient data (size: 67)
# Skipping 88749.0 due to insufficient data (size: 14)
# Skipping 88785.0 due to insufficient data (size: 137)
# Skipping 88802.0 due to insufficient data (size: 53)
# Skipping 88846.0 due to insufficient data (size: 199)
# Skipping 88866.0 due to insufficient data (size: 125)
# Skipping 88907.0 due to insufficient data (size: 95)
# Skipping 88938.0 due to insufficient data (size: 13)
# Skipping 88952.0 due to insufficient data (size: 66)
# Skipping 88972.0 due to insufficient data (size: 37)
# Skipping 89005.0 due to insufficient data (size: 125)
# Skipping 89032.0 due to insufficient data (size: 57)
# Skipping 89104.0 due to insufficient data (size: 62)
# Skipping 89132.0 due to insufficient data (size: 150)
# Skipping 89133.0 due to insufficient data (size: 176)
# Skipping 89223.0 due to insufficient data (size: 99)
# Skipping 89239.0 due to insufficient data (size: 48)
# Skipping 89259.0 due to insufficient data (size: 158)
# Skipping 89260.0 due to insufficient data (size: 121)
# Skipping 89276.0 due to insufficient data (size: 90)
# Skipping 89306.0 due to insufficient data (size: 144)
# Skipping 89354.0 due to insufficient data (size: 120)
# Skipping 89374.0 due to insufficient data (size: 167)
# Skipping 89388.0 due to insufficient data (size: 157)
# Skipping 89389.0 due to insufficient data (size: 142)
# Skipping 89396.0 due to insufficient data (size: 168)
# Skipping 89400.0 due to insufficient data (size: 102)
# Skipping 89414.0 due to insufficient data (size: 86)
# Skipping 89423.0 due to insufficient data (size: 36)
# Skipping 89448.0 due to insufficient data (size: 12)
# Skipping 89457.0 due to insufficient data (size: 140)
# Skipping 89559.0 due to insufficient data (size: 143)
# Skipping 89569.0 due to insufficient data (size: 63)
# Skipping 89639.0 due to insufficient data (size: 121)
# Skipping 89640.0 due to insufficient data (size: 72)
# Skipping 89706.0 due to insufficient data (size: 137)
# Skipping 89794.0 due to insufficient data (size: 33)
# Skipping 89829.0 due to insufficient data (size: 157)
# Skipping 89871.0 due to insufficient data (size: 150)
# Skipping 89884.0 due to insufficient data (size: 150)
# Skipping 89890.0 due to insufficient data (size: 195)
# Skipping 89929.0 due to insufficient data (size: 42)
# Skipping 89957.0 due to insufficient data (size: 72)
# Skipping 89963.0 due to insufficient data (size: 72)
# Skipping 90021.0 due to insufficient data (size: 122)
# Skipping 90167.0 due to insufficient data (size: 95)
# Skipping 90420.0 due to insufficient data (size: 166)
# Skipping 90667.0 due to insufficient data (size: 126)
# Skipping 90712.0 due to insufficient data (size: 99)
# Skipping 90721.0 due to insufficient data (size: 134)
# Skipping 90848.0 due to insufficient data (size: 44)
# Skipping 91140.0 due to insufficient data (size: 165)
# Skipping 91150.0 due to insufficient data (size: 156)
# Skipping 91180.0 due to insufficient data (size: 131)
# Skipping 91323.0 due to insufficient data (size: 145)
# Skipping 91388.0 due to insufficient data (size: 171)
# Skipping 91738.0 due to insufficient data (size: 191)
# Skipping 91842.0 due to insufficient data (size: 175)
# Skipping 91846.0 due to insufficient data (size: 175)
# Skipping 92113.0 due to insufficient data (size: 161)
# Skipping 92114.0 due to insufficient data (size: 164)
# Skipping 92117.0 due to insufficient data (size: 162)
# Skipping 92194.0 due to insufficient data (size: 185)
# Skipping 92225.0 due to insufficient data (size: 197)
# Skipping 92595.0 due to insufficient data (size: 133)
# Skipping 92649.0 due to insufficient data (size: 183)
# Skipping 92650.0 due to insufficient data (size: 183)
# Skipping 92651.0 due to insufficient data (size: 188)
# Skipping 92652.0 due to insufficient data (size: 188)
# Skipping 92653.0 due to insufficient data (size: 178)
# Skipping 92654.0 due to insufficient data (size: 183)
# Skipping 92656.0 due to insufficient data (size: 188)
# Skipping 92657.0 due to insufficient data (size: 178)
# Skipping 92698.0 due to insufficient data (size: 160)
# Skipping 92715.0 due to insufficient data (size: 93)
# Skipping 92798.0 due to insufficient data (size: 106)
# Skipping 92799.0 due to insufficient data (size: 47)
# Skipping 92838.0 due to insufficient data (size: 55)
# Skipping 92853.0 due to insufficient data (size: 154)
# Skipping 93241.0 due to insufficient data (size: 193)
# Skipping 93242.0 due to insufficient data (size: 193)
# Skipping 93250.0 due to insufficient data (size: 163)
# Skipping 93326.0 due to insufficient data (size: 127)
# Skipping 93327.0 due to insufficient data (size: 127)
# Skipping 93328.0 due to insufficient data (size: 127)
# Skipping 93348.0 due to insufficient data (size: 197)
# Skipping 93405.0 due to insufficient data (size: 193)
# -----------------------------------
# Calculating beta_t
#
# Skipping 10012 due to insufficient data (size: 147)
# Skipping 10089 due to insufficient data (size: 39)
# Skipping 10108 due to insufficient data (size: 154)
# Skipping 10453 due to insufficient data (size: 166)
# Skipping 10691 due to insufficient data (size: 82)
# Skipping 10906 due to insufficient data (size: 40)
# Skipping 10935 due to insufficient data (size: 165)
# Skipping 11216 due to insufficient data (size: 168)
# Skipping 11262 due to insufficient data (size: 79)
# Skipping 11358 due to insufficient data (size: 167)
# Skipping 11371 due to insufficient data (size: 19)
# Skipping 11393 due to insufficient data (size: 168)
# Skipping 11473 due to insufficient data (size: 121)
# Skipping 11483 due to insufficient data (size: 73)
# Skipping 11485 due to insufficient data (size: 61)
# Skipping 11643 due to insufficient data (size: 54)
# Skipping 11646 due to insufficient data (size: 39)
# Skipping 11794 due to insufficient data (size: 133)
# Skipping 11803 due to insufficient data (size: 118)
# Skipping 11851 due to insufficient data (size: 90)
# Skipping 11901 due to insufficient data (size: 31)
# Skipping 12107 due to insufficient data (size: 180)
# Skipping 12174 due to insufficient data (size: 47)
# Skipping 12177 due to insufficient data (size: 117)
# Skipping 12265 due to insufficient data (size: 102)
# Skipping 12311 due to insufficient data (size: 137)
# Skipping 12346 due to insufficient data (size: 36)
# Skipping 12396 due to insufficient data (size: 197)
# Skipping 12485 due to insufficient data (size: 51)
# Skipping 12544 due to insufficient data (size: 27)
# Skipping 12591 due to insufficient data (size: 191)
# Skipping 12593 due to insufficient data (size: 192)
# Skipping 12594 due to insufficient data (size: 196)
# Skipping 12595 due to insufficient data (size: 196)
# Skipping 12596 due to insufficient data (size: 196)
# Skipping 12600 due to insufficient data (size: 191)
# Skipping 12601 due to insufficient data (size: 191)
# Skipping 12602 due to insufficient data (size: 191)
# Skipping 12603 due to insufficient data (size: 191)
# Skipping 12604 due to insufficient data (size: 191)
# Skipping 12605 due to insufficient data (size: 191)
# Skipping 12606 due to insufficient data (size: 191)
# Skipping 12607 due to insufficient data (size: 191)
# Skipping 12608 due to insufficient data (size: 191)
# Skipping 12609 due to insufficient data (size: 191)
# Skipping 12610 due to insufficient data (size: 191)
# Skipping 12611 due to insufficient data (size: 191)
# Skipping 12612 due to insufficient data (size: 191)
# Skipping 12613 due to insufficient data (size: 191)
# Skipping 12614 due to insufficient data (size: 191)
# Skipping 12615 due to insufficient data (size: 196)
# Skipping 12623 due to insufficient data (size: 190)
# Skipping 12624 due to insufficient data (size: 197)
# Skipping 12625 due to insufficient data (size: 190)
# Skipping 12627 due to insufficient data (size: 161)
# Skipping 12628 due to insufficient data (size: 190)
# Skipping 12632 due to insufficient data (size: 192)
# Skipping 12633 due to insufficient data (size: 197)
# Skipping 12636 due to insufficient data (size: 191)
# Skipping 12640 due to insufficient data (size: 194)
# Skipping 12641 due to insufficient data (size: 177)
# Skipping 12644 due to insufficient data (size: 184)
# Skipping 12645 due to insufficient data (size: 179)
# Skipping 12646 due to insufficient data (size: 177)
# Skipping 12647 due to insufficient data (size: 177)
# Skipping 12648 due to insufficient data (size: 177)
# Skipping 12649 due to insufficient data (size: 177)
# Skipping 12651 due to insufficient data (size: 177)
# Skipping 12652 due to insufficient data (size: 177)
# Skipping 12653 due to insufficient data (size: 177)
# Skipping 12654 due to insufficient data (size: 177)
# Skipping 12655 due to insufficient data (size: 177)
# Skipping 12656 due to insufficient data (size: 176)
# Skipping 12657 due to insufficient data (size: 176)
# Skipping 12658 due to insufficient data (size: 176)
# Skipping 12659 due to insufficient data (size: 176)
# Skipping 12660 due to insufficient data (size: 189)
# Skipping 12661 due to insufficient data (size: 181)
# Skipping 12662 due to insufficient data (size: 172)
# Skipping 12663 due to insufficient data (size: 172)
# Skipping 12664 due to insufficient data (size: 187)
# Skipping 12665 due to insufficient data (size: 180)
# Skipping 12666 due to insufficient data (size: 173)
# Skipping 12667 due to insufficient data (size: 184)
# Skipping 12668 due to insufficient data (size: 189)
# Skipping 12671 due to insufficient data (size: 187)
# Skipping 12672 due to insufficient data (size: 187)
# Skipping 12673 due to insufficient data (size: 180)
# ...
# Skipping 81290.0 due to insufficient data (size: 55)
# Skipping 81483.0 due to insufficient data (size: 128)
# Skipping 81510.0 due to insufficient data (size: 152)
# Skipping 81590.0 due to insufficient data (size: 35)
# Skipping 81601.0 due to insufficient data (size: 130)
# Skipping 81636.0 due to insufficient data (size: 189)
# Skipping 81672.0 due to insufficient data (size: 14)
# Skipping 81709.0 due to insufficient data (size: 19)
# Skipping 81710.0 due to insufficient data (size: 103)
# Skipping 81726.0 due to insufficient data (size: 115)
# Skipping 81865.0 due to insufficient data (size: 41)
# Skipping 81904.0 due to insufficient data (size: 24)
# Skipping 82236.0 due to insufficient data (size: 157)
# Skipping 82294.0 due to insufficient data (size: 14)
# Skipping 82478.0 due to insufficient data (size: 23)
# Skipping 82511.0 due to insufficient data (size: 187)
# Skipping 82549.0 due to insufficient data (size: 67)
# Skipping 82680.0 due to insufficient data (size: 97)
# Skipping 82681.0 due to insufficient data (size: 130)
# Skipping 82724.0 due to insufficient data (size: 61)
# Skipping 82767.0 due to insufficient data (size: 136)
# Skipping 82805.0 due to insufficient data (size: 129)
# Skipping 83163.0 due to insufficient data (size: 97)
# Skipping 83236.0 due to insufficient data (size: 5)
# Skipping 83295.0 due to insufficient data (size: 7)
# Skipping 83334.0 due to insufficient data (size: 25)
# Skipping 83404.0 due to insufficient data (size: 145)
# Skipping 83444.0 due to insufficient data (size: 61)
# Skipping 83455.0 due to insufficient data (size: 93)
# Skipping 83456.0 due to insufficient data (size: 100)
# Skipping 83478.0 due to insufficient data (size: 125)
# Skipping 83496.0 due to insufficient data (size: 134)
# Skipping 83581.0 due to insufficient data (size: 145)
# Skipping 83590.0 due to insufficient data (size: 96)
# Skipping 83650.0 due to insufficient data (size: 77)
# Skipping 83657.0 due to insufficient data (size: 121)
# Skipping 83764.0 due to insufficient data (size: 38)
# Skipping 83813.0 due to insufficient data (size: 90)
# Skipping 83918.0 due to insufficient data (size: 72)
# Skipping 83926.0 due to insufficient data (size: 147)
# Skipping 83967.0 due to insufficient data (size: 106)
# Skipping 84133.0 due to insufficient data (size: 18)
# Skipping 84136.0 due to insufficient data (size: 143)
# Skipping 84193.0 due to insufficient data (size: 147)
# Skipping 84211.0 due to insufficient data (size: 97)
# Skipping 84223.0 due to insufficient data (size: 159)
# Skipping 84229.0 due to insufficient data (size: 146)
# Skipping 84232.0 due to insufficient data (size: 183)
# Skipping 84240.0 due to insufficient data (size: 11)
# Skipping 84307.0 due to insufficient data (size: 158)
# Skipping 84369.0 due to insufficient data (size: 65)
# Skipping 84431.0 due to insufficient data (size: 67)
# Skipping 84508.0 due to insufficient data (size: 21)
# Skipping 84525.0 due to insufficient data (size: 105)
# Skipping 84536.0 due to insufficient data (size: 47)
# Skipping 84605.0 due to insufficient data (size: 9)
# Skipping 84629.0 due to insufficient data (size: 181)
# Skipping 84650.0 due to insufficient data (size: 170)
# Skipping 84659.0 due to insufficient data (size: 62)
# Skipping 84666.0 due to insufficient data (size: 173)
# Skipping 85005.0 due to insufficient data (size: 93)
# Skipping 85057.0 due to insufficient data (size: 80)
# Skipping 85073.0 due to insufficient data (size: 189)
# Skipping 85197.0 due to insufficient data (size: 38)
# Skipping 85202.0 due to insufficient data (size: 29)
# Skipping 85210.0 due to insufficient data (size: 3)
# Skipping 85267.0 due to insufficient data (size: 135)
# Skipping 85304.0 due to insufficient data (size: 4)
# Skipping 85358.0 due to insufficient data (size: 192)
# Skipping 85431.0 due to insufficient data (size: 23)
# Skipping 85458.0 due to insufficient data (size: 108)
# Skipping 85463.0 due to insufficient data (size: 132)
# Skipping 85495.0 due to insufficient data (size: 199)
# Skipping 85620.0 due to insufficient data (size: 67)
# Skipping 85624.0 due to insufficient data (size: 126)
# Skipping 85740.0 due to insufficient data (size: 5)
# Skipping 85816.0 due to insufficient data (size: 133)
# Skipping 85817.0 due to insufficient data (size: 43)
# Skipping 85874.0 due to insufficient data (size: 165)
# Skipping 85890.0 due to insufficient data (size: 184)
# Skipping 85933.0 due to insufficient data (size: 72)
# Skipping 85950.0 due to insufficient data (size: 96)
# Skipping 86037.0 due to insufficient data (size: 44)
# Skipping 86063.0 due to insufficient data (size: 69)
# Skipping 86156.0 due to insufficient data (size: 60)
# Skipping 86194.0 due to insufficient data (size: 186)
# Skipping 86215.0 due to insufficient data (size: 86)
# Skipping 86224.0 due to insufficient data (size: 98)
# Skipping 86248.0 due to insufficient data (size: 145)
# Skipping 86259.0 due to insufficient data (size: 194)
# Skipping 86268.0 due to insufficient data (size: 10)
# Skipping 86293.0 due to insufficient data (size: 125)
# Skipping 86401.0 due to insufficient data (size: 54)
# Skipping 86447.0 due to insufficient data (size: 112)
# Skipping 86579.0 due to insufficient data (size: 14)
# Skipping 86591.0 due to insufficient data (size: 195)
# Skipping 86748.0 due to insufficient data (size: 194)
# Skipping 86758.0 due to insufficient data (size: 106)
# Skipping 86761.0 due to insufficient data (size: 103)
# Skipping 86770.0 due to insufficient data (size: 25)
# Skipping 86813.0 due to insufficient data (size: 159)
# Skipping 86885.0 due to insufficient data (size: 104)
# Skipping 86913.0 due to insufficient data (size: 123)
# Skipping 86917.0 due to insufficient data (size: 103)
# Skipping 87030.0 due to insufficient data (size: 128)
# Skipping 87060.0 due to insufficient data (size: 114)
# Skipping 87079.0 due to insufficient data (size: 148)
# Skipping 87085.0 due to insufficient data (size: 169)
# Skipping 87087.0 due to insufficient data (size: 128)
# Skipping 87093.0 due to insufficient data (size: 178)
# Skipping 87095.0 due to insufficient data (size: 23)
# Skipping 87100.0 due to insufficient data (size: 137)
# Skipping 87147.0 due to insufficient data (size: 180)
# Skipping 87227.0 due to insufficient data (size: 55)
# Skipping 87228.0 due to insufficient data (size: 188)
# Skipping 87241.0 due to insufficient data (size: 199)
# Skipping 87248.0 due to insufficient data (size: 31)
# Skipping 87281.0 due to insufficient data (size: 193)
# Skipping 87283.0 due to insufficient data (size: 193)
# Skipping 87293.0 due to insufficient data (size: 94)
# Skipping 87385.0 due to insufficient data (size: 87)
# Skipping 87387.0 due to insufficient data (size: 38)
# Skipping 87401.0 due to insufficient data (size: 63)
# Skipping 87412.0 due to insufficient data (size: 68)
# Skipping 87425.0 due to insufficient data (size: 135)
# Skipping 87435.0 due to insufficient data (size: 111)
# Skipping 87465.0 due to insufficient data (size: 37)
# Skipping 87472.0 due to insufficient data (size: 185)
# Skipping 87621.0 due to insufficient data (size: 145)
# Skipping 87642.0 due to insufficient data (size: 155)
# Skipping 87795.0 due to insufficient data (size: 20)
# Skipping 87826.0 due to insufficient data (size: 137)
# Skipping 87828.0 due to insufficient data (size: 123)
# Skipping 87839.0 due to insufficient data (size: 83)
# Skipping 88156.0 due to insufficient data (size: 24)
# Skipping 88158.0 due to insufficient data (size: 189)
# Skipping 88180.0 due to insufficient data (size: 179)
# Skipping 88187.0 due to insufficient data (size: 108)
# Skipping 88198.0 due to insufficient data (size: 164)
# Skipping 88256.0 due to insufficient data (size: 125)
# Skipping 88270.0 due to insufficient data (size: 80)
# Skipping 88273.0 due to insufficient data (size: 170)
# Skipping 88275.0 due to insufficient data (size: 179)
# Skipping 88305.0 due to insufficient data (size: 73)
# Skipping 88393.0 due to insufficient data (size: 119)
# Skipping 88418.0 due to insufficient data (size: 129)
# Skipping 88425.0 due to insufficient data (size: 92)
# Skipping 88431.0 due to insufficient data (size: 50)
# Skipping 88441.0 due to insufficient data (size: 76)
# Skipping 88460.0 due to insufficient data (size: 125)
# Skipping 88500.0 due to insufficient data (size: 95)
# Skipping 88527.0 due to insufficient data (size: 193)
# Skipping 88578.0 due to insufficient data (size: 176)
# Skipping 88585.0 due to insufficient data (size: 118)
# Skipping 88622.0 due to insufficient data (size: 114)
# Skipping 88625.0 due to insufficient data (size: 168)
# Skipping 88631.0 due to insufficient data (size: 2)
# Skipping 88651.0 due to insufficient data (size: 62)
# Skipping 88737.0 due to insufficient data (size: 67)
# Skipping 88749.0 due to insufficient data (size: 14)
# Skipping 88785.0 due to insufficient data (size: 137)
# Skipping 88802.0 due to insufficient data (size: 53)
# Skipping 88846.0 due to insufficient data (size: 199)
# Skipping 88866.0 due to insufficient data (size: 125)
# Skipping 88907.0 due to insufficient data (size: 95)
# Skipping 88938.0 due to insufficient data (size: 13)
# Skipping 88952.0 due to insufficient data (size: 66)
# Skipping 88972.0 due to insufficient data (size: 37)
# Skipping 89005.0 due to insufficient data (size: 125)
# Skipping 89032.0 due to insufficient data (size: 57)
# Skipping 89104.0 due to insufficient data (size: 62)
# Skipping 89132.0 due to insufficient data (size: 150)
# Skipping 89133.0 due to insufficient data (size: 176)
# Skipping 89223.0 due to insufficient data (size: 99)
# Skipping 89239.0 due to insufficient data (size: 48)
# Skipping 89259.0 due to insufficient data (size: 158)
# Skipping 89260.0 due to insufficient data (size: 121)
# Skipping 89276.0 due to insufficient data (size: 90)
# Skipping 89306.0 due to insufficient data (size: 144)
# Skipping 89354.0 due to insufficient data (size: 120)
# Skipping 89374.0 due to insufficient data (size: 167)
# Skipping 89388.0 due to insufficient data (size: 157)
# Skipping 89389.0 due to insufficient data (size: 142)
# Skipping 89396.0 due to insufficient data (size: 168)
# Skipping 89400.0 due to insufficient data (size: 102)
# Skipping 89414.0 due to insufficient data (size: 86)
# Skipping 89423.0 due to insufficient data (size: 36)
# Skipping 89448.0 due to insufficient data (size: 12)
# Skipping 89457.0 due to insufficient data (size: 140)
# Skipping 89559.0 due to insufficient data (size: 143)
# Skipping 89569.0 due to insufficient data (size: 63)
# Skipping 89639.0 due to insufficient data (size: 121)
# Skipping 89640.0 due to insufficient data (size: 72)
# Skipping 89706.0 due to insufficient data (size: 137)
# Skipping 89794.0 due to insufficient data (size: 33)
# Skipping 89829.0 due to insufficient data (size: 157)
# Skipping 89871.0 due to insufficient data (size: 150)
# Skipping 89884.0 due to insufficient data (size: 150)
# Skipping 89890.0 due to insufficient data (size: 195)
# Skipping 89929.0 due to insufficient data (size: 42)
# Skipping 89957.0 due to insufficient data (size: 72)
# Skipping 89963.0 due to insufficient data (size: 72)
# Skipping 90021.0 due to insufficient data (size: 122)
# Skipping 90167.0 due to insufficient data (size: 95)
# Skipping 90420.0 due to insufficient data (size: 166)
# Skipping 90667.0 due to insufficient data (size: 126)
# Skipping 90712.0 due to insufficient data (size: 99)
# Skipping 90721.0 due to insufficient data (size: 134)
# Skipping 90848.0 due to insufficient data (size: 44)
# Skipping 91140.0 due to insufficient data (size: 165)
# Skipping 91150.0 due to insufficient data (size: 156)
# Skipping 91180.0 due to insufficient data (size: 131)
# Skipping 91323.0 due to insufficient data (size: 145)
# Skipping 91388.0 due to insufficient data (size: 171)
# Skipping 91738.0 due to insufficient data (size: 191)
# Skipping 91842.0 due to insufficient data (size: 175)
# Skipping 91846.0 due to insufficient data (size: 175)
# Skipping 92113.0 due to insufficient data (size: 161)
# Skipping 92114.0 due to insufficient data (size: 164)
# Skipping 92117.0 due to insufficient data (size: 162)
# Skipping 92194.0 due to insufficient data (size: 185)
# Skipping 92225.0 due to insufficient data (size: 197)
# Skipping 92595.0 due to insufficient data (size: 133)
# Skipping 92649.0 due to insufficient data (size: 183)
# Skipping 92650.0 due to insufficient data (size: 183)
# Skipping 92651.0 due to insufficient data (size: 188)
# Skipping 92652.0 due to insufficient data (size: 188)
# Skipping 92653.0 due to insufficient data (size: 178)
# Skipping 92654.0 due to insufficient data (size: 183)
# Skipping 92656.0 due to insufficient data (size: 188)
# Skipping 92657.0 due to insufficient data (size: 178)
# Skipping 92698.0 due to insufficient data (size: 160)
# Skipping 92715.0 due to insufficient data (size: 93)
# Skipping 92798.0 due to insufficient data (size: 106)
# Skipping 92799.0 due to insufficient data (size: 47)
# Skipping 92838.0 due to insufficient data (size: 55)
# Skipping 92853.0 due to insufficient data (size: 154)
# Skipping 93241.0 due to insufficient data (size: 193)
# Skipping 93242.0 due to insufficient data (size: 193)
# Skipping 93250.0 due to insufficient data (size: 163)
# Skipping 93326.0 due to insufficient data (size: 127)
# Skipping 93327.0 due to insufficient data (size: 127)
# Skipping 93328.0 due to insufficient data (size: 127)
# Skipping 93348.0 due to insufficient data (size: 197)
# Skipping 93405.0 due to insufficient data (size: 193)
# c:\Users\YeonChan Kang\anaconda3\envs\fdb\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\YeonChan Kang\AppData\Local\Temp\ipykernel_155632\2447871842.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rho = rho_model.params[1]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\YeonChan Kang\anaconda3\envs\fdb\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mktrf'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 sw_beta = cal_beta_sw(test_data, 'date', 'permno', 'ret', 'mktrf', '12M', True)
#
# Cell In[175], line 47, in cal_beta_sw(data, date, id, ret, mkt, period, dataframe)
#      44 beta_sw_t = beta_sw / se_beta_sw
#      46 # Calculate alpha using beta_sw
# ---> 47 X_sw = sm.add_constant(beta_t[idx][mkt] * beta_sw)  # Using beta_sw
#      48 y_sw = beta_t[idx][ret]
#      50 model_sw = sm.OLS(y_sw, X_sw)
#
# File c:\Users\YeonChan Kang\anaconda3\envs\fdb\lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\YeonChan Kang\anaconda3\envs\fdb\lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'mktrf'

# %% [markdown]
# #### Dimson (1979) beta

# %% [markdown]
# Dimson (1979) shows that when a stock is infrequently traded, estimating of beta using the CAPM model can be severely biased.
#
# Dimson(1979) beta is defined as:
# $$ \beta_{i}^{D} = \sum_{k=-5}^{k=5} \hat{b}_{i}^k$$
# where the $$\beta_{i}^{k}$$ are the estimated slope coefficients from the regression model:
# $$ r_{i,t} = a_i + \sum_{k=-5}^{k=5} \beta_{i}^{k} MKT_{t+k} + e_{i,t}

# %% [markdown]
# In this chapter, we calculate $\beta^D$ for stock $i$ in __month__ $t$ using one year's worth of daily return data for t-11 through t.

# %%
def calculate_dimson_beta(data, id, ret, mkt, period, lag_range=5, dataframe=False):
    """
    Calculate Dimson Beta by summing the betas over a range of lags.
    """
    dimson_betas = []

    for lag in range(-lag_range, lag_range + 1):
        # Shift the market return by the lag
        data[f'{mkt}_lag_{lag}'] = data.groupby(id)[mkt].shift(-lag)
        
        # Calculate beta for the shifted data
        beta_results = cal_beta(data, id, ret, f'{mkt}_lag_{lag}', period, dataframe=dataframe)
        
        # Append the calculated betas to the list
        dimson_betas.append(beta_results[['beta']])
    
    # Sum the betas across all lags to get Dimson Beta
    dimson_beta = sum(dimson_betas)
    data['dimson_beta'] = dimson_beta
    
    return data

# %% [markdown]
# # 2. Summary Statistics

# %% [markdown]
# As same as winsorizing we skip the explanation of functions to caculate Summary Statistics.
#
# For more on this, see Ch2. Summary Statistics

# %% [markdown]
# 126p
